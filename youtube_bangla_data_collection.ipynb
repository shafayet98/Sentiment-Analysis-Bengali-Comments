# %%
import os
import re
import numpy as np
import pandas as pd
import string

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

# %%
# Provide youtube api key, channel Id, Client Secret File
yt_api_key = ""
channel_id = ""

# %%
# Initializing and Connecting Youtube API
from apiclient.discovery import build
youtube = build('youtube','v3', developerKey = yt_api_key)

# %%
search_item = []
for i in range(2005,2021):
    track = 'bangla natok '+ str(i)
    search_item.append(track)

# %%
vidIds = []
for each_natok in search_item:
    req = youtube.search().list(q = each_natok, part = 'snippet', type = 'video', maxResults = 100)
    res = req.execute()
    items_res = res["items"]
    for itm in items_res:
        vidIds.append(itm["id"]["videoId"])

# %%
uniqVid = set(vidIds)

# %%
len(uniqVid)
# Out:
# 659

# %%
# getting all the command from video ids
all_comments = []
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD8B1pPJ6hgPGnYBrcCinKim4B_ClQPpzc"
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)
for uid in uniqVid:
    try:
        request = youtube.commentThreads().list(
                part="id,snippet,replies",
                maxResults=100,
                videoId= uid
            )
        response = request.execute()
        for i in range(len(response["items"])):
            each_comment = response["items"][i]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
            all_comments.append(each_comment)
        print("Done")
    except:
        print("Forbidden")
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Forbidden
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Forbidden
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done

# %%
# import json
# # print(json.dumps(res))
# with open('data.json', 'w') as outfile:
#     json.dump(res, outfile)

# %%
# with open('comment.json', 'w') as outfile:
#     json.dump(response, outfile)

# %%
len(all_comments)
# Out:
# 49691

# %%
# len(response["items"])

# %%
def remove_english_words(lines):
    sentences = []
    for i in range(len(lines)):
        temp = lines[i]
        lst = temp.split()
        flag = 0
        for word in lst:
            x = re.search(r"^[a-zA-Z0-9]", word)
            if x:
                flag += 1
        if flag == 0:
            sentences.append(temp)
    return sentences

# %%
comments = remove_english_words(all_comments)

# %%
len(comments)
# Out:
# 25120

# %%
comments[16000:]
# Out:
# ['💓💓💓💓💓💓💓',
#  'তিশা আপু আপনার অভিনয় এত সুন্দর',
#  'নাটক টা অনেক ভাল লাগছে ভাই অনেক সুন্দর হয়েছে',
#  'সর্দার নিটারে টাঙ্গাইলের পতিতা পল্লীর সর্দার আছে না ঠিক ঐরকম লাগে আগে কি উনি টাঙ্গাইলের পতিতা পল্লীর সর্দার ছিল',
#  '১০. ১২. ২০২০ আন্দামান দ্বীপপুঞ্জে থেকে',
#  'চাকুর ভিতেের  অকটও নাই',
#  'এককথায় অসাধারণ।',
#  'বাংলা বড় পর্দার অভিনেত্রী শাবনূর।<br>আর ছোট পর্দার অভিনেত্রী তিশা।<br><br>সত্যিই এদের বিকল্প হয় না।',
#  'একদম বাস্তব চিত্র।',
#  'কেন এমন হয়.😢😢আমাদের নারিদের উপর.',
#  'তিশার অভিনয় টা অসাধারন ❤️❤️❤️🌷🌷🌷🌷',
#  'সুন্দর লাগছে',
#  'যার কেহ নেই তার কাছে আল্লাহ  তায়ালা আছেন',
#  'আমি মোশাররফ - তিশার বড় ফ্যান। তাদের দুজনের জুটি সেরা, কে কে একমত আছেন!',
#  'তিশা তোমার তুলোনা নেই👌👌👌👌👌',
#  'এক কথায় অসাধারণ 👉👉👉👉👍<br>বাস্তব জীবনের কাহিনী 💓💓💓💓',
#  'তিশা অভিনীত নাটক ভালো লাগে',
#  'এটায় আমাদের সমাজ',
#  'গল্পের গাথুনি খুব সুন্দর ছিল, ভালো লাগছে।',
#  'গল্প ভাল,,,, তিশার অসাধারণ অভিনয়,,,, তবে কিছু সংলাপ আর যৌনতার বিষয়গুলো এতটা স্পষ্ট ভাবে তুলে না ধরলেও হত,,,',
#  'দারুন',
#  'নাটক জগতের তিশা সব চেয়ে ভাল অভিনেত্রী ।।।।',
#  'বাস্তব নাটক',
#  'খূব সুন্দর কাহিনী খুব ভালো পরিচালনা এবং অপূর্ব অভিনয় দেখে মুগ্ধ।',
#  'তিশার অসাধারণ অভিনয়।।তোমার চলার পথ আরো সুন্দর সুখময় হোক।ঈশ্বর যেন সদা তোমার সহায় থাকেন ।।(গড়িয়া, কলকাতা)',
#  'সত্যি অসাধারণ তিশা আপু জিনিয়াস',
#  'তিশা একজন ভালো অভিনেত্রী',
#  '♥♥♥♥♥♥',
#  'অসাধারন',
#  'কাম করা শ্রমিক এর এইটুক হাতা ব্লাউজ।',
#  'ভাই তিন টেক্কা নাটক দিন,,, আদুর কাদের সারের',
#  'আসলে আগের নাটক গুলা তে অন্যরকম এক সৌন্দর্য ছিল সবকিছু জানো ন্যাচারাল',
#  '💜💛💚💓💖💟💗',
#  '❤️💙💚',
#  'নাটকটা তেমন ভালো না এই রকম-👍👎',
#  'হায়রে কাল্পনিক ভালোবাসার কাহিনী।। 😭😭',
#  'শুধু নাটকেই কেনো? <br>বাস্তবে কেনো শেষ টা এত সুন্দর হয় না!😔',
#  'আসাধরন ছিল',
#  'ঠিক এই কারনে অপূর্ব ভাইয়া অার মেহেজাবীন আপুর  নাটক দেখি',
#  'এত টিং টং শব্দ না দিলে হয় না শব্দের জন্য কথা ভালভাবে শোনা যায়না',
#  'খুব সুন্দর হয়েছে নাটকটা❤️❤️',
#  'আশা করি সকলের কাছে নাটকটি ভালো লেগেছে, <br><br>আমাদের জন্য সবসময় দোয়া করবেন যেন আপনাদের ভালো কিছু উপহার দিতে পারি  🥀🥀',
#  'অসম্ভব সুন্দর নাটক ❤️<br>পুরোটা দৃশ্যই ইমোশনাল ছিলো বলে আরও ভালো লাগলো 🍀🌿',
#  'নাটকে  অপূর্বের নাম কি ???',
#  'ক্যারিয়ার এর জন্য অনেক ভালোবাসা ভেঙ্গে যায়...😥😥',
#  'কি লিখব বুঝতে পারছি না চোখ বন্ধ হয়ে গেছে',
#  'মেহজাবিন কতো সাদামাটা থাকে একদম সিমপ্ল',
#  'ক্যারিয়ার আর ভালবাসা দুটো একসাথে হয় 😟',
#  'কতো কিছু মিল পাওয়া যায় আসলে নাটক থেকে♥️<br>শেষ টা দারুন🥰',
#  'এক কথাই অসাধারন দৃশ্যে ছিল❤️❤️😍😍❤️❤️😍😍',
#  'অসাধারণ অভিনয় দুই জনের ।খুব ভালো লেগেছে ।ধন্যবাদ টিমের সবাই কে ।',
#  'এই নাটকটা এতো সুন্দর তারপরও ১০ মিলিয়ন হলো না।',
#  '🖤🖤🖤🖤🖤🔥🔥🔥🔥🔥',
#  '🖤🖤🖤🖤🔥🔥🔥',
#  'অনেক ভালো লাগল🥰🥰🥰',
#  'গিবটা অসাধারণ , লেখাগুলো অনেক অনেক ভালো লেগেছে',
#  'মেহজাবিন,তিশা, তিশা নাজনিন এই সব নায়িকাদের নাটক দেখতে আর ভালোলাগেনা।নতুন মুখ দেখতে চাই।',
#  'সেরা জুটি আমার  খুব  ভালো  লাগে',
#  'এই পৃথীবিতে মেয়েরা পারেনা,,,  তেমন কিছু নেই,, আমার মতে,,,  যে পাএ তাকে, তার রূপ নেয়??',
#  '❣️❣️❣️❣️',
#  'সত্যি অসাধারণ ছিলো',
#  'অসাধান',
#  'অপুর্ব ভাইয়া এবং মেহেজাবিন আপু আপনাদের নাটকে গল্প টা অসাধারণ সুন্দর মিস ইউ অপুর্ব ভাইয়া এবং মেহেজাবিন আপু',
#  'যত দেখি আরো বেশি দেখতে ইচ্ছা করে কেনো জানিনা',
#  'আমি মনে করি সব থেকে বেশি নাটক দেখি এত ভাল লাগে একটার পর একটা সময়টা কোন দিখে চলে যায় বুঝতে পারছি না।',
#  'সত্যিই খুব ভাল লাগল। হৃদয় ছুঁয়ে গেছে।',
#  'নাটকটি খুব ভালো লাগলো !',
#  'অনেক অনেক সুন্দর হইছে...ধন্যবাদ..',
#  'ভালো থাকার জন্য দরকার মানসিক শান্তি! আর আমরা মানসিক শান্তি তার কাছেই পাই যারে আমরা ভালোবাসি🙂',
#  'অপূর্ব ভাই ও মেহজাবিন আপু 💗💗💗 অসাধারণ 👌👌👌💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞',
#  'সময়ের কাছে আমরা প্রতিনিয়ত হেরে  যায়।দুরত্ব হলে বুঝা যায় ভালাবাসার টান।',
#  'খুব সুন্দর নাটকটি। দেখে ভালো লাগলো। অপূর্ব আর মেহজাবিন এর অভিনয় দারুণ হয়সে ❤️❤️❤️❤️❤️❤️',
#  'নাটকটা ৯০ % আমার  জীবনে  সাথে  মিল আছে  আমার   সবচেয়ে  প্রিয় মানুষটা  হরি  গেছে  আজ টাকা  আছে  কিন্তু  প্রিয় মানুষটস নাই',
#  'সব গল্পের শেষ যদি এমন হতো 😇',
#  '❤️❤️❤️❤️❤️❤️❤️❤️ভালোবাসা কি সেটা শুধু যে ভালোবাসে সে বোঝে.....',
#  '❤️❤️❤️',
#  'কিছু নাটকের পরিনতি কখনোই ভোলা যায় না .এইটাও ওইরকম নাটক 💝',
#  'প্রতিটা গল্পের শেষ যদি এমন হতো, তাহলে হয়তো আমিও আমার ভালবাসার মানুষটাকে পেয়ে যেতাম 😔',
#  '❤❤',
#  'মিউজিক শোনা যাচ্ছে, অনেক সংলাপ শোনা যাচ্ছেনা।',
#  'সত্যিকারের ভালোবাসাগুলো কখনোই পূর্নতা পায় না।১০০% এর মধ্যে ৯৯% ভালোবাসাই বাস্তবতার কাছে হেরে যায়।এটাই হয়তো নিয়তি।😔😔',
#  'নাটকটা অনেক সুন্দর, আমরা এরকম নাটক চাই',
#  '💕💕♥️😛💕😍😍🤫🤩💔💔💔💔',
#  'ধন্যবাদ',
#  'সালার শুয়োর টা এভাবে আহ আহ করছে কেন 😂',
#  'আমার দেখা একটি সেরা নাটক। শিখার অনেক কিছু আছে।',
#  'সুুটিংয়ের আয়োজন দেখলে মনে হয় বিশ্রো যুদ্ধুো করতেছে',
#  'অসাধারণ মৌলিক নাটক',
#  'রিটায়ার্ড অার্মি অফিসার যে সাধারণ মানুষের সাথে মিলতে পারে না তা অাবার প্রমাণ পেলাম।।',
#  'ঠ',
#  'আগের নাটক গুলো যে কতটা মার্জিত,  তা এখনকার নাটক গুলোর সাথে পার্থক্য করলেই বুঝা যায়। হারিয়ে ফেলেছি এই সোনালী দিনের নাটক গুলো। স্ক্রিপ্ট, ডিরেকশন, অভিনয় সবকিছু মিলে অসাধারণ।',
#  'এই রকম পরিবার যদি আমার হতো',
#  'আবুল হায়াত স্যার, আপনি অসাধারণ। আপনি  সুস্থ থাকুন এবং ভালো থাকুন। চন্দন সাহা। কোলকাতা। ভারত।',
#  'খান টেস্ট',
#  'আবুল হায়াত স্যারের অভিনয় আমার খুব ভলো লাগে',
#  '.',
#  'সবই ঠিক আছে শুধু জেলি টা ছাড়া।<br>কেন না এমন কোন অদ্ভুত জেলি যদি থাকতো যেটা মানুষের চরিত্রকেই সংশোধন করে দিতে পারে তবে বাংলা কেন পৃথিবীর বুকে এমন কোন ঘুসখোর ব্যক্তি থাকতে পারতো না।<br>নাটকে আনন্দের জন্য উল্লাসের জন্য খন্ডচিত্র দেয়া খারাপ না।<br>তবে এমন কোন চিত্র ঠিক বলে আমি মনে করি না। <br>যার কোন অস্তিত্ব পৃথিবীর বুকে নেই_______যেমন নাটকে আবিষ্কৃত জেলি।',
#  'পূর্বপুরুষ যখন &#39;খান বংশের&#39; হাতচানি দেয় তখন সেই ঘরের নাতিপুতিরা তো একেকজন একেক কাজে &#39;খান হবেই&#39;।<br>এটাতো বংশের নিয়ম-নীতি তাই না?',
#  'আমার গুরু হায়াৎ',
#  'চমৎকার,,,,লেগেছে,,,তিশার,,,অবিনয়টা,,,♥♥♥♥♥',
#  'বাস্তোবে এমন জাল্লাদ  শাশুড়ির ঘরে কেউ থাকবেনা   এখানে শশুরের অভিনয় ভালছিলো কিন্তু সে প্রতিবাদ করেনাই ও চনচল ভাই ও কনো বাড়ার প্রতিবাদ করেনাই ,  সবার অভিনয় অনেক ভালো ছিলো কিন্তু তার অভিনয়টা অনেক খারাপ ছিলো শাশুড়ি চরিত্রে  ওনাকে এমন একটা অভিনয় না করাটাই ভালো ছিলো আমার অনেক খারাপ লেগেছে।',
#  'অনেক দিন আবার দেখলাম।',
#  'নাটক আর জীবন মিলে মিশে একাকার',
#  'বর্তমান যুগের যে সমস্ত নাটক এগুলো থেকে কোন বাস্তবতা শিক্ষা পাওয়া যায় না তার চেয়ে পুরনো নাটক গুলো খুবই সুন্দর হয় এবং বাস্তবতা ফুটে উঠে',
#  'অসাধারণ',
#  'বাস্তবধর্মী নাটক।',
#  'বউগুলা আসলেই এমনই হয়',
#  'শাশুড়ি ও বৌর অভিনয়ে চোখে জল না এসে পারল না।',
#  'বলার ভাষা নেই, খুভ সুন্দর হয়েছে....',
#  'অনেক ভালো লাগলো, যদিও বাস্তবতার সাথে মিল আছে',
#  'এইরকম শাশুড়ি অনেক ঘরে আছে',
#  'আম্মার সাথে দেখছিলাম<br>দেখলাম মার চোখে পানি😥',
#  'নাটকের প্রথম অংশ আমার সাথে পুরো পুরি মিল <br>কিন্তু লাস্টের অংশের সঙ্গে কোনো মিল নেই <br>এই নাটকের মেটার অনেক কপাল ভালো <br>আর আমার কপাল অসাধারণ <br>হা হা হা হা হা হা হা হা হা হা',
#  '💞💞💞',
#  'নাইচ',
#  'বাস্তবধর্মী',
#  'সালাউদ্দীন লাভলু মানেই নতুন কোনো চমক',
#  'বুড়ীর অভিনয় সব নাটকেই এরকম',
#  'এটা ঠিক।',
#  'যারা যারা অবিবাহিত তারা এ নাটকটি দেখে অনেক কিছু শেখার আছে',
#  'শিক্ষনীয় নাটক',
#  'এক কথায় অসাধারণ',
#  'নাটকতো হওয়া উচিত এমন একেবারে বাস্তব যেনো সামনে ধরাদে',
#  'খাটি বাংগালী নাটক',
#  'সেই কবে দেখছিলাম <br>আজ ১০ বছর পর আবার নতুন রুপ',
#  'এত ভাল লাগছে, বলার ভাষা নাই',
#  'অনেক সুন্দর হয়েছে,',
#  'আসলে আমাদের মত মেয়েদের জীবটাই এমন',
#  'আমার মা এবং বাবা সেইম এই রকম,,,,, মাঝখানে আমি এখন ব্যাচেলার,,,,বউ হইলে মনে হয় পুরো কাহিনি আমার জীবনে ঘটবে,,,,তার পূর্বাভাস পাচ্ছি',
#  'তিন্নি আপুর অভিনয়টা একদম রিয়েলিস্টিক ছিলো!😍',
#  'শাশুড়ির শেষ উক্তি গুলো খুবই ভালো লাগলো',
#  'অসাধারণ একটা নাটক। বাস্তবতার সঙ্গে দারুণ মিল',
#  'অসাধারণ চরিত্র কাল্পনিক চিত্রটি দেখতে অনেক সুন্দর, ভালো.....?',
#  'সত্যি অনেক সুন্দর।।।।',
#  'কি অপূর্ব, কি অভিনয়, কি পরিচালনা, নাটক নয় যেন বাস্তব জীবন, এত ভালো লাগলো, চোখের জল পড়বেই এ নাটক দেখলে, অভিভূত<br>কলকাতা থেকে.....',
#  'এই নাটক গুলো দিন দিন হারিয়ে যাচ্ছে',
#  'এটাই জীবন',
#  'বাংলার সংস্কৃতি ঐতিহ্য ও সামাজিকতায় সব সয়ম এমন দৃশ্য প্রতি ঘরে ঘরে বিরাজমান। এই দৃশ্য আমার ও আপনার সকল  পরিবারের।',
#  'এর আগে দেখেছিলাম একটা নাটক সার্ভিস হোল্ডার<br>আজকে দেখলাম এই নাটক টি<br>কি বলবো বলার ভাষা নেই<br>এক কথায় অসাধারণ',
#  'আমার  মায়ের  জীবনের  সাথে মিলে  গেছে',
#  'আমার জিবনে বেস্ট  নাটক ১০ আফ ১০',
#  'সত্যিই অসাধারণ',
#  'অনেক সুন্দর নাটক',
#  'যার বাবা নাই সে জানে বাবা কি জিনিস',
#  'অসাধারণ!',
#  'হৈমন্তি,  গল্পটা পড়ে,  আসল চেহারাগুলো সামনে ভেসেছিলো!  আর আজ &quot;বউ&quot; নাটক টা দেখে,  চোখে পানি চলে আসলো 😭 ,  সবার ঘড়ে-ই মেয়ে আছে !  কবে শুধরাবে এই মানুষ নামের যন্তুু গুলা ? ,  লেখক-পরিচালক- অভিনেতা - সবাইকে অনেক ধন্যবাদ  👍',
#  '😭😭😭',
#  'মাটির বাড়ি মাটির ঘর মাটির হবে ঠিকানা সেই মাটিতে শুইতে হবে,সেজাগায় নাই বিছানা',
#  'নাটকটি বাস্তবের সাথে অনেক মিল আছে সালাউদ্দিন লাভলুর নাটক মানেই নাম্বার ওয়ান',
#  'এত কান্দিস নারে তোরা। মানুশ আমারে পগল কয়',
#  'ভুল থেকে সত্যি বেরিয়ে আসে 🤔🤔🤔',
#  'এই রকম শাশুড়ি কে জুতা মারা উছিত',
#  'বাস্তবের সাথে পুরো মিল',
#  'সুন্দর নাটক',
#  'দেখে অনেক ভালো লাগলো বাস্তব চিএ,,,',
#  'সব শ্বাশুড়িই বউকে কোনদিন সহ্য করতে পারেননা। 😂😂😂😂😂😂',
#  'শাশুরির অভিনয়টা অনেক ভালো হয়েছে',
#  'চোখে পানি ধরে রাখতে পরলামনা।😰😰<br>সবাইকে অনেক অনেক ধন্যবাদ। 🙋🙋',
#  'অসাধারণ  চ\u200d্যানেল আই কে অসংখ্য  ধন্যবাদ',
#  'আমি এক এক করে সবার কমেন্ট দেখলাম( বিশেষ করে মেয়েদের) একজন মেয়ে ও বল্লনা জে শাশুড়ির অভিনয় খুব ভাল হয়েচে♥আহারে নারি♥সবোই ঠেলা গাড়ি♥ যখন বুড়ি হবে♥ তখন ঠিক বুজবে♥♥',
#  'এই নাটকটা বাস্তব থেকে বাড়ানো হয়েছে। কিন্তু লাস্ট সিনারি টা এটা বাস্তবের সাথে মিল নাই। কারণ কোন শাশুড়ি তার ভুল স্বীকার করে না না না',
#  'সবার জীবন  যদি নাটকের শেষ অংশের মতো হতো',
#  'অসাধারণ গল্প,চরিত্রায়ন 💖🥀🥀',
#  'এই বাড়ি হারকিপ্টা নাটকের হারাদনের বাড়ি',
#  'অা খ ম হাসান এর টাংগাইলের ভাষাটা ভালো ছিলো।',
#  'সুন্দর পরিবেশনা।',
#  'আগের তুলনায় এখন আর শাশুরিরা এরকম হয় না।।। কারন সবাই শিক্ষিত বর্তমানে।।।',
#  'তিন্নি অলদা বেষ্ট।।।',
#  'আমি আগে কমেন্ট গুলো পড়ি তারপর নাটক দেখি কমেন্টস পল্লী নাটকের গুণগতমান সম্বন্ধে একটা প্রাথমিক ধারণা পাওয়া যাই কে কে আছেন আমার মত',
#  'নমস্কার নমস্কার বাংলাদেশ 🙏🙏🙏',
#  'ডাঃ এজাজ এর চরিত্র টা একদম বরিং।  এর জায় গায় অন্য কোন আর্টিস্ট হলে বোধহয় ভালো হয়।  একদমই ফালতু লাগে কচু।  সরি।',
#  '১২ পর্ব কৈ খুজে পাইনা তো',
#  '৮ পর্ব পর থেকে কথা সোনা যায় না এটা ঠিক করেন',
#  'অসাধারণ  ওহ ওহ ওহ হাঃ হাঃ হাঃ।',
#  '❤️❤️❤️',
#  'আহ্ জীবন!সত্যিই অন্য জগতের অনুভূতিতে নিমগ্ন হয়ে যাই এই ছবিটা দেখতে দেখতে।',
#  'ভালো লাগার মত অসাধারণ একটি মুভি',
#  'নেটওয়ার্কের বাইরে ওয়েব ফিল্ম টি দেখার পরে কে কে দেখতে আসছেন?',
#  '😌😌',
#  'অসাধারণ ছবিটা 💞💞💞',
#  'অসাধারন ছিলো মুভিটা ৩০/০৮/২০২১',
#  'যতবার দেখি ততবারই ভালো লাগে। আহ! মধ্যবিত্তের জীবন 💞😑💞😑💞',
#  'খুব আফসোস হয়, যখন এই মুভিটা দেখি, কান্না আসে, ছোট্ট বেলা মনে পড়ে যায়, মনটা তখন খুব ছোট হয়ে যায়।',
#  'অসম্ভব সুন্দর ❤️',
#  'পল্টুর সাথে আমার অনেক অনেক মিলে গেছে',
#  'অসাধারণ  লাগলো',
#  'বল্টু ভাই কি এবার ও যেতে পারবেনা????',
#  'অনেক বছর পরে বাংলা মুভি দেখলাম',
#  'দারিদ্র্যতা জে কতটা ভিতরগত বেথা বুজানো জাবে না',
#  'পুরো মুভির মাজে একটা গালিও নাই হইল এইটা, আর আমরা এখন গালি ছারা নাটক করি না দেখতে হবে আমাদের',
#  'এইগুলা হইছে ফ্রেন্ডশিপের মুভি ❤️<br><br>আর কোথাকার কি বালছাল &quot;নেটওয়ার্কের বাইরে&quot; যেখানে বন্ধুর গার্লফ্রেন্ডরে সাথে ফিজিক্যাল করে ঐটা নিয়া লাফালাফি! <br><br>হ্লাগোর চয়েজ দেখলেই বমি আসে 🤮🤮',
#  '-দারিদ্র্য আমারে ভালোবাসার ক্ষমতা নষ্ট করে ফেলেছে 🙂🙂',
#  'অসাধারন',
#  'বন্ধুত্বের ব্যাপারটাই আলাদা😍<br>কিন্তু সবচেয়ে বেশি আনন্দের ব্যাপার হচ্ছে শেষ পর্যন্ত সবাই এক সাথে যেতে পারলো💖💖',
#  'আহা স্মৃতি',
#  'আমি আজ প্রথম মুভিটা দেখলাম।অনেক সুন্দর।শেষ সিন টা বেশি সুন্দর।শেষে যখন মেয়ে টাকেও ট্রেনে তুলে নিল।অনেক ভাল লাগলো।💚',
#  'এটার কাছে নেটওয়ার্কের বাইরে কোনকিছু?',
#  'আবেগ ধরে রাখতে পারছি না 😘😘<br>এতো ভালো লাগে কেন আমার 😊🥰',
#  'চলে যাচ্ছি দারুচিনি দ্বীপ ♥️ ২০২১ এ আরেকবার নেটওয়ার্কের বাহিরে 😬😍',
#  'ভ্রমনপ্রেমী মানুষের অবশ্যই ভালো লাগবে এমন কিছু সিনেমা 😍😍',
#  'অসম্ভব সুন্দর একটা মুভি 🥰',
#  'নেটওয়ার্কের বাইরে নাটকটা দেখে আবারও এটা দেখতে কে কে এসেছেন..?',
#  'অনেক সন্দর মনে রাখার মতো একটি টেলিছবি...♥',
#  'ঈদের সময় এই সিনেমা টা হতো তখন ডিস ছিল না সবাই বসে সিনেমা দেখতাম অনেক সুন্দর অনুভূতি ছিল🥰',
#  'বাংলাদেশের এবং বাংলার শ্রেষ্ঠ কবি,সাহিত্যিক,ঊপন্যাসিক ও চলচিত্রকার স্যার হুমায়ুন আহমেদ ১০০%। আলহামদুলিল্লাহ, কারন বাংলাদেশ হুমায়ুন আহমেদ এর মত এক নক্ষত্র পেয়েছিল। তবে কেন জানি মহান আল্লাহ পাক বাংলাদেশের সম্পদ গুলো তাড়াতাড়ি নিয়ে নেন?  হুমায়ুন আহমেদ, জহির রায়হান, সুকান্ত ভট্টাচার্য, কাজী নজরুল ইসলাম হারিয়ে গেছেন অকালে। কিন্তু বর্তমানের নাটকগুলো জোকার, ধরনেন, বনিতা বেশি, জোর করে হাসানোর চেষ্ঠা অথচ হুমায়ুন আহমেদ এর সাটক কথা আর অভিনয় দেখেই আপনি আমি হাঁসতে বাধ্য।',
#  'গল্পো হয়তো শেষ হৃয়দ তো নয়',
#  'আমার রুমের থেকে চাঁদ দেখা যায় ঐ দিকে তাকিয়ে ছবি টা শেষ',
#  'দারুচিনি দ্বীপ &gt;&gt;&gt; নেটওয়ার্কের বাইরে',
#  'আবার দেখতে আসলাম পুরোতন স্মৃতি আওড়াতে।এ ছবি দেখেই বন্ধুদের নিয়ে ঘুড়তে যাবার স্বপ্ন দেখতাম।',
#  'প্রয়াত আবদুল্লাহ আল মামুনের অভিনয় এবং সংলাপ ছবিটিতে অন্য মাত্রা যোগ করেছে। মাপা সংলাপ কিন্তু সরস।',
#  'এগুলো কখনো ও পুরোনো হবার নয়,,',
#  'আমার মত ২০২১ আসে কে কে দেখেছেন',
#  'অসম্ভব সুন্দর একটা মুভি।।।',
#  'ক্লাস ৭-৮ এ থাকাকালীন ইদ এর দিন বিকেলে দিতো মুভি টা ❤<br>কি সুন্দর আর সাবলীল ছিলো দিন গুলো <br>যতই বড়ো হচ্ছি আনন্দ গুলো সব নিস্তেজ হয়ে যাচ্ছে',
#  'হুমায়ূন আহমেদের উপন্যাস, নাটক,সিনেমা মানেই যেন একটা পৃথিবী আর সেখানকার বাসিন্দা আমরা সবাই! বাংলাদেশ এ শুধুমাত্র উনার নাটক সিনেমা দেখেই প্রচুর হেসেছি আবার অনেক কেদেছি। ছোট বেলা থেকেই উনার সকল কাজ আমার মনে দাগ কেটেছে, এটাও তার ব্যতিক্রম নয়।',
#  'নেটওয়ার্কের বাইরে দেখার করে মুভিটার কথা মন পড়লো।<br>তাই আবার নতুন করে দেখতে চলে এলাম',
#  'সকালের হাসি দিয়ে শেষ হলো <br><br>শেষটা প্রশান্তির ছিল❤️',
#  '২০২১এ এসে মুভিটা দেখছি৷ 🥰',
#  'এত বছর পর আবার দেখে কি যে ভালো লাগলো',
#  'ভালো থাকুন পৃথিবীর সকলের প্রিয় বাবা😍',
#  '২০২১ এ (আজ) আমি দেখলাম। গতকাল নেটওয়ার্ক এর বাইরে ওয়েব ফিল্ম দেখেছি।অনেকটা মিল আছে',
#  'অসম্ভব সুন্দর একটা কাহিনী 🙂<br>বাস্তবতার সাথে যেন একবারে মিলে যায়। <br>কি সাবলীল সবার অভিনয়,  বচন ভঙগি💕',
#  'নতুন রিলিজ &quot;নেটওয়ার্কের বাইরে&quot; দেখে আবার আসলাম এই মাস্টারপিস দেখতে,  একটাই অনুরোধ হুমায়ুন আহমেদের মাস্টারপিস এর সাথে ঐটার সাদৃশ্য করবেন না কেউ প্লিজ।😐😐',
#  '২৪.০৮.২০২১ দেখছি।',
#  'কি সুন্দর রে ভাই! ২০২১ সালে এসে আবার দেখছি। আগের মতোনই ফিলিংস রয়েছে। 💖💖',
#  'নেটওয়ার্কের বাইরে ওয়েব সিরিজ দেখার পর এই মুভির কথা মনে পড়লো। বন্ধুত্বের ব্যাপারটা প্রায় একই❤️',
#  'আমি আজ দেখলাম। ২০২১সালে কে কে দেখছেন তারা লাইক দিন',
#  'নেটওয়ার্কের বাইরে দেখার পর দেখতে আসলাম।',
#  'প্রিয় তিনিটি মুভির মধ্যে বরাবরই এক নম্বরে।',
#  'অসম্ভব সুন্দর 🥰',
#  'অসাধারণ বাংলা ছবি।',
#  'একটা মুভি এতোটা সুন্দর হয় কি ভাবে?',
#  '২০২১ সালে দেখছি',
#  'নেটওয়ার্কের বাইরে দেখার পর দেখতে আসছি।।।।',
#  'নেটওয়ার্কের বাইরে দেখার পর কে দেখত আসছন.....?😊<br>আমি ২৩/৮/২০২১<br>আর আপনি..?🤔',
#  'ভালোবাসার সময় গুলো',
#  'নেটওয়ার্কের বাইরে নামে একটা মুভি এসেছে সবাই এই দারুচিনি দ্বীপ এর সাথে কম্পেয়ার করতেছে!!<br>আমার মনে হয় না এটা কখনো সম্ভব!! দারুচিনি দ্বীপের  গল্পটার প্রতি আলাদা একটা মায়া আছে আর সেটা সারা জীবন থেকেই যাবে',
#  'নেটওয়ার্ক এর বাইরে দেখে এই মুভির কথা মনে পড়ে গেলো আবার',
#  'আহা কী সাবলীল বাচনভঙ্গী😻',
#  'এতো সুন্দর মুভি আগে কেন দেখিনি 🙄🙄🙄🙄 বিনোদন এ ভরপুর বাস্তবতা ফুটিয়ে তুলেছে অভিনয়ে তো একজন একজন লিজেন্টডারি🖤🖤🖤🖤🖤',
#  '২০২১ সালে এসে  ও কে কে এই মুভিটা দেখতে আসেন?',
#  'নেটওয়ার্ক মুভি দেখার পর এটা দেখতে আসলাম',
#  'রহিম ভাই এখানে আসান রবি চেংগু নাইবারি বুমবল সব ভাদাইমার গোসটি ভিডিও করলে ভাল হইত',
#  'তার ছেড়া এগুলো কোনো কৌতুক হলো',
#  'কান কাটা রহিম পাগল নাকি কলার গাছ নাচ করতে পারে',
#  'রহিম  একটু বেশি একটিং করে',
#  'সুন্দর',
#  'অনেক সুনদুর হয়েছে তারছিড়া সোনামিয়া ভাই আর রুবির আপুর দুইজনের অভিনয় সেইরকম হয়েছে',
#  'ফালতূ কমেডী',
#  'নাইস ভিডিও শোনা ভাই  পিচ্চি তো  দারুন অভিনয় করে ওকে দিয়ে আপনি  কৌতুক বানান',
#  'মজা পাইলাম সোনা ভাই ও কালা চান ভাই',
#  'বালের কৌতুক',
#  'রুবি আপনাকে আর মিষ্টি কে আমি শপনে দেখি',
#  'খুভ বালা লাকছে আর জাতরা ডান্স চাই বিষষ্টি আর রুবি💃',
#  'সোনা ভাই আপনার অভিনয় অসাধারণ আর রহিম ভাই ও অসাধারণ অভিনয় করে আপনার সব সময় এক সাথে কৌতুক করবেন প্লিজ',
#  'সোনা ভাই কেমন আছেন',
#  'আসসালামু আলাইকুম',
#  'রুবি',
#  'রুবি তুমি আমাকে পাগল করেছ',
#  'গাজি ভাইয়ের নাচ টা খুব সুন্দর',
#  'সোনা মিয়া মানে অসাধারণ কিছু',
#  'আমি আছি স্রক ছেলে',
#  'আপনাদের ফান অনেক সুন্দর লাগে',
#  'অসাধারন ফান',
#  'ভালো লাগলো',
#  '😁😁😁😁😁😆😆😆',
#  'ভাই রহিম ভাইকে সব সময় রাখবেন',
#  'তাঁরছিরা ভাই আমি কোলকাতা থেকে বলছি ভালো কৌতুব',
#  'সেই',
#  'ডাল আর চাল না দিলে যেমন খিচুরি হয় না । ঠিক তেমনি সোনা ভাই আর রহিম ছাড়া ভাদাইমা হয় না।',
#  'দারুন',
#  'সোনা ভাই সেরা',
#  'ডান্স একাডেমি নায়িকা চোখ টেরা কেন নতুন ডান্স শিক্ষা নাকি নাকি ডান্স করতে গিয়ে এ সমস্যা হয়েছে বাদাইমা হয়তো ভালো ডান্সের শিখিয়েছে',
#  'রুভি রে সেই লাগে',
#  'যারা কমেডি বানান তাদের কে বলছি। কাজল আর রুবি সাথে সোনা মিয়া কমেডি বানাবেন। কাজল আার রুবি অভিনয় আমার ভালো লাগে।',
#  'অনেক অনেক সুন্দর হয়েছে ভিডিও',
#  'রহিম ভাইকে অনেক ভাল লাগে',
#  'নাইচ',
#  'রুবির সাথে আমি দেখা করতে চাই।<br>রুবির ঠিকানাটা দেয়া যাবে কি।',
#  'চুদার জন্য সেক্সি ছেলে চাই,স্বামী বিদেশ, আমাকে এড কর',
#  'জীবন্ত অভিনয়',
#  'মুই গর্বিত মুই বরিশাইল্লাহ।',
#  'অনেক  অনেক  সুন্দর করছেন',
#  'অসাধারন ভাই',
#  'হাত দইরা কয় মারিস না 😜😜😜😜',
#  'ভাই তোমাদের সাথে কথা  বলা  জায়',
#  'অসাধারন',
#  'অসাধারণ লাগল ভাই',
#  'মাল ভাই, খুব ভালো হচ্ছে আপনাদের টিমের ভিডিও। প্রতিটি ভিডিও আগের পর্বকে  অতিক্রম করছে ভালো লাগার দিক থেকে। ভালবাসা অবিরাম ❤<br><br><br><br>  জামাই, আর জামাইর মামুরে নাইহোলের ডাউগ্গা দিয়া বানান ডা খুব ভালো হইছে। লগে যদি মুগোউর বা গাবের কাঠ দিয়া দিতেন হেলে সুখ হইতো। 😁',
#  'সুন্দর হইছে<br><br>আপনাদের মেয়ে চরিত্রটি ইনপ্রুভ করা প্রয়োজন',
#  'ওয়াও কি ভাবে সম্ভব এতো সুন্দর ভিডিও বানানো',
#  'অনেক সুন্দর হয়েছে',
#  '👍👍👍',
#  'অসাধারণ হইছে, <br>হাসতে হাসতে শেষ! <br>পরের পর্বের জন্য অধির আগ্রহে অপেক্ষা করছি!',
#  'অনেক অনেক শুভ কামনা রইল কুয়াকাটা মাল্টিমিডিয়ার সকল সদস্যদের জন্য',
#  'খুব ভালো হইছে  অসাধারন ❤️❤️❤️❤️💗💗',
#  'পরের পর্ব কোন সময় দিবেন?',
#  'ভাই এই পর্ব টা চরম হইছে। যদি একটু কোহিনুর চরিত্র আনতেন তাহলে আরেকটু ভালো হতো মনে হয়।',
#  'আজ পরিবারের সবাইকে নিয়ে দেখলাম। প্রান খুলে সবাই আনন্দ উপভোগ করেছি। অনাবদ্ধ ছিলো......',
#  'আমতলী থেকে ভালোবাসা ওভিরাম (এটা আমতলীর চ্যানেল)',
#  'সাদ্দাম মাল 🥳',
#  'খুব ভালো লাগছে সাবাইকে  ধন্যবাদ',
#  'শেষটা দারুণ ছিল,, হাসতে হাসতে শেষ আমি',
#  'দেশি ফ্যান।',
#  'অসাধারণ',
#  '❤️❤️❤️❤️❤️❤️❤️❤️',
#  'ভিডিওটি অনেক সুন্দর হয়েছে 🤏💥🤏♥️🤏♥️🤏♥️🤏♥️🤏♥️🤏♥️🤏♥️🤏♥️🤏♥️♥️♥️🤏👉🤏♥️🤏♥️♥️♥️♥️♥️',
#  'অনেক সুন্দর  ভিডিও   আপনাদের সব ভিডিও  দেখি আমার  বাসাও পটুয়াখালী',
#  'ভালোবাসা অবিরাম ❤️<br>দোয়া রইল ভাই 💓<br>সামমে এগিয়ে জান, ❤️💓',
#  '☺️❤️',
#  'বাই  আমি আপনাগো  সব ভিডিও  দেখি',
#  'খুব ভাল হয়েছে',
#  'অনেক অনেক ভালো লাগলো ধন্যবাদ টিমের সবাইকে',
#  'মাই ফাদার ইজ এ চোর!! অসাধারণ  হইছে।',
#  'ভাল লাগল ধানখালি থেকে',
#  'এই পর্ব টা বেস্ট চিলো',
#  'অনেক সুন্দর হইছে ❤️',
#  'অসাধারণ ভাই',
#  '❤️❤️❤️❤️',
#  'অস্থির হইছে ভালবাসা অভিরাম♥️♥️',
#  'পর্ব ৩ হইলে এপিসোড ২ হয় ক্যাম্নে?',
#  '💟💟💟💟',
#  '❤❤❤',
#  '🔥-😘Ꮇ α Ꮥ н α ℓ ℓ 🅰 н 😍🔥<br><br>           🔥-বাহ-!🔥-<br><br>                   🔥-অসাধারন-!🔥',
#  'ওরেএএ মাল🔥<br>সেরা অভিনয় সেরা😘',
#  'ভাই  পিরোজপুর থেকে ভালোবাসা অবিরাম',
#  'ভাই এই ভিডিওটা জদি, মরা লোক ও দেখো তাহলে সেও হাসতে হাসতে খারাইয়া জাবে। সুন্দর  হইছে ভাই।  এই পব টার জন্য অনেক অপেক্ষা করছি, আমি তো হাসতে হাসতেসেস।😂😂😂🤪🤪😂😂😂🤣🤣🤭🤭🤭🤭😄😄😄',
#  'ভাই অনেক সুন্দার হইছে ভাই এগিয়ে জান ভাই দোয়া রইলো সব সময়',
#  'অসাধারণ একটা নাটক',
#  'আরো পর্ব চাই',
#  'মাই ফাদার ইজ এ চোর এই ডায়লগটা জোস ছিলো ।',
#  '💚',
#  'আসাধারন হইছে',
#  'অসাধারণ 💕💗💓',
#  'হাসাহাসির কারখানা',
#  'সাদ্দাম ভাই নাসির মামা কি বানানডাই না খাইছো ওরে বাবা',
#  '🤣🤣🤣🤣🤣🤣🤣🤣',
#  'বলার ভাষা নাই ভাই অসাধারণ হয়েছে পরবর্তী পর্বের জন্য অধীর আগ্রহে রইলাম',
#  '💛💛💛💛💛💛',
#  'গলাচিপা, <br>আমখোলা থেকে',
#  '৪ পর্ব চাই',
#  'আমার বাড়ি কুয়াকাটা ❤️❤️',
#  'পিডা মালরে পিডা।।। চমৎকার অভিনয়।',
#  'পরের পার্ট কবে ভাই।অপেক্ষায় আছি',
#  'অসাধারন😍',
#  'ধানখালি নমোরহাট বাজার,এর কাছে,,<br><br><br>ভাই আপনাদের জন্য দোয়া ও ভালবাসা অবিরাম',
#  'এক ছের বালায়াগে',
#  '😄😄😄😄😄😄😄😄😄',
#  'ভাই ভিডিও টা দেখে অনেক মজা পাইলাম',
#  'যোশ হইচে,,,,,ভাল পাইয়া মাইয়া দেলাম ভাইগ্নাড্ডে হেয়ানেও তিনডা গুরাগারা😅😂😄😃😅😅😂😂,অসাধারন অভিনয় করেন আপনারা,,, শুভ কামনা রইল,,,❤️',
#  'অনেক সুন্দর হইছে 🥰😍🥀<br>ভালোবাসা অবিরাম আপনাদের জন্য ❤️🥀❤️',
#  'সাদ্দাম ভাই সেরা',
#  'পরের পর্ব কবে নাগাদ পাবো',
#  '💙🖤🔥',
#  'অনেক সুন্দর হইছে',
#  'আমার দেখা সবথেকে সেরা নাটক।খুবই মিস করি সেই সব দিন গুলাকে।এখন ও এমন নাটক মাঝে মাঝে দেখা জায়।তবে আগের মতন এতো প্রানবন্ত না।',
#  'তখন ক্লাস ১১ তে পড়তাম যখন প্রথম দেখেছিলাম নাটক টা।<br> আজ ৫ বছর পর আবার ও দেখছি।<br>ভালোলাগে খুব।❤️',
#  '৬ বছর থেকে এক টানা দেখতেছি।এখনো মোবাইলে ডাউনলোড করা আছে।এখন পর্যন্ত প্রিয় নাটক❤️',
#  'আজ ০৫/০৮/২০২১ তারিখে আবারো দেখা',
#  'সেই সময়ে নাটক গুলো অনেক ভাল লাকতো। মবাইল কম ছিল কোন গেম খেলে সময় পার করতো না।',
#  'তাহসান ভাইয়ের ভালো কয়েকটি নাটকের নাম বলে যান,,, আমি দেখবো',
#  '২০২১ সাল থেকে দেখছি,তবু্ও কাদছি',
#  'আমার জীবনে কোন নাটক প্রথম দেখলাম৷২০১৬তে দেখলাম এর পর তাহসানের সব নাটক দেখলাম',
#  'প্রথম ভালোলাগার নাটক। ❣️',
#  'বাংলাদেশ মুভি লাভারস এ রিভিউ পেয়ে ফিরে আসলাম 🥰😍',
#  'মন কেমনের ভালোবাসা।<br>তাহসান আপনাকে কুর্ণিশ।',
#  'ওআও। অসম্ভব ভালো লাগলো।সত্যি।!!!!!',
#  '২০২১এসে  কারা দেখতেছেন',
#  'কুত্তার বাচ্চারা নাটকে অর্ধেক কাহীনি নাই।নকল আপলোড করচস।',
#  'আশ্চর্য রকমের পরিচ্ছন্ন একটি নাটক। অসম্ভব ভাল লাগল ।',
#  'সুন্দর নাটক ❤️',
#  'নাটকটি অনেক বার দেখেছি অসাধারণ',
#  'নাটকের প্রতি ভালোবাসা এই নাটক দিয়েই শুরু।।',
#  'এই নাটকটা যখন প্রথম দেখি তখন ক্লাস ফাইবে পড়ি। আজ আবার দেখলাম এখন কলেজ লাইফে চলে আসছি  ভালো লাগাটা আগের মতই আছে।',
#  'চমৎকার নাটকের কাহিনী, চমৎকার অভিনয় তাহশান ও মম&#39;র, চমৎকার  হৃদয় জুড়ানো গান।শিহাব ভাইকে অনেক অনেক অনেক ধন্যবাদ। চমৎকার একটা নাটক উপহার দেওয়ার জন্য।',
#  '১লা ডিসেম্বর, ২০২১ সালে আবারও দেখছি।',
#  'প্রায় অনেক আগে দেখছিলাম নাটকটা, এরপরে নামটা  পুরোপুরি মনে ছিলনা শুধু নীলান্জনা নাম টা মনে ছিল, শুধু নীলান্জনা সার্চ করে নাটকটা যে আর কতবার দেখছি হিসাব নেই, ২০২০ এর শেষের দিকে আবার দেখলাম, বছরগুলা একেক করে টিকি চলে যাবে শুধু সৃতি হিসেবে কমেন্টগুলা থেকে যাবে।',
#  'বলার কিছুই নেই শুধু বলবো অসাধারণ,,,,,',
#  'আমার দেখা সেরা নাটক  ,',
#  'এমন গল্প আর মেকিং আজকাল আর হয়না :)',
#  'মম রে দেখে ক্রাশ খাইলাম',
#  '২০১৫ সালে দেখে ছিলাম আজ মনে পরে গেল তাই দেখলাম আবার অসাধারণ',
#  'আমার কাছে প্রথম স্মার্টনেস মানে তাহসান ভাই🌼আমার কাছে প্রথম আধুনিকতার নাম তাহসান ভাই🌸<br>আমার প্রথম ভালোবাসার আবেগগুলোর বহিঃপ্রকাশ তাহসান ভাই🌺<br>সেই ২০১৩ র নীলপরি নীলান্জনা থেকে আজ ২০২০ পর্যন্ত আপনার স্মৃষ্টির জন্যে<br>আপনি আমার কাছে সেরা হয়ে ছিলেন,,   আছেন,,থাকবেন,,সবসময়✌✌',
#  'অনেকের কাছে নাটকটার কথা শুনে দেখতে এসেছি।দেখে যা বুঝলাম, আমি ও অন্যদের দেখার কথা বলতে পারব।খুব সুন্দর একটা নাট।সময়টা ভালো কেটেছে।',
#  'বাহ',
#  'মম আপুর জন্যই নাটক দেখি কারন ওনার অভিনয় আমার খুব ভালো লাগে',
#  'মজাই কমেনা এতো দেখলাম নাটকটা',
#  'ওয়াও! ব্যকগ্রাউন্ড এ মিনার ভাইয়ের গান তাহসান ভাইয়ের নাটকে! বাহ',
#  'নাইস নাটক',
#  '২০২০ এ কে কে দেখছেন???',
#  'আমার অনেক পোছন্দ',
#  'আমার ভালো লাগা.................',
#  'মন খারাব লাগলে এটা দেখি।মন ভালো হয়ে যায়।',
#  'আমার জীবনের সবচেয়ে বেস্ট নাটক 😍😍😍😍😍',
#  'অনেক অংশ কাটা কেন<br>এন টিভির থেকে আমরা এটা আশা করিনি',
#  'আমার জীবনের সবচেয়ে গুরুত্বপূর্ণ নাটক এটা যত দেখি দেখার ইচ্ছা বাড়ে',
#  'নাটকের অনেক অংশ নেই',
#  'আমার খুব প্রিয় একটি নাটক।',
#  'অনেকবার দেখেছি এখনও ভাল লাগে।',
#  'কেন হঠাৎ তুমি এলে--',
#  'আ\u200cফ্রো\u200cদি\u200cতি- গ্রীক সৌন্দর্য্য ও প্রে\u200cমে\u200cর দেবী।',
#  'অনেকদিন পর আবার দেখলাম..... দারুন গল্প দারুন অভিনয়',
#  'যেন প্রকৃতিক ভালবাসায়  নাটক টি গড়া',
#  'মীর সাব্বির এর নতুন ধারাবাহিক নাটক &quot;বাকের খনি&quot;',
#  'সালাউদ্দিন লাভলুর নাটক মানেই, অসাধারন&quot;',
#  'পুরাতন নাটকগুলো খুব সুন্দর ❤️❤️❤️ আধুনিক নাটক গুলোর কারণে ঔ নাটকগুলোর গুরুত্ব বোঝা যায় না❤️❤️❤️',
#  'দেখতেছি',
#  'এই নাটকের চরিএটা চন্চলের সাথে যায় না।তাই ডিস লাইক দিলাম',
#  'আমার প্রিয় দুই অভিনেতা আছে। আখম হাসান চঞ্চল চৌধুরী',
#  'সুন্দর একটা নাটক',
#  '😃😃😃😄🙃😉😉',
#  'পরিচালকের কাহিনি দেখে তারপর কাজে হাত দেয়া উচিৎ ছিল',
#  'সুন্দর একখানা প্রেমের উপাখ্যান।',
#  'কুয়েত থেকে দেখছি 🇧🇩',
#  '“তোমার ঐ হাসি দেখলে মনে হয় চাঁদের জোৎস্নার আলো,<br>ঐ আলো মনে হয় আমার উপর টপটপ বৃষ্টির মতো ঝুপুরঝাপুর পরে...আমি ভিজে যাই”<br>😁🤣😂',
#  'গ্রামের নাটকের মত আর নাটক বানাবেন চনচল কে নিয়ে',
#  'কিছু কথোপকথন নাটকের মান নামিয়ে দিয়েছে। বিশেষ করে নায়ক হাত বাঁধা অবস্থায় মা সহ উপস্থিত সবার সামনে ঘটকের উক্তি টেনে বিবাহের কথা বলে।এ হয়তো ওদেশের পক্ষে মানানসই!',
#  'সালাউদ্দিন লাভলু ভাই আপনার পরিচালোনা করা নাটক এক কথায় গ্রামের পরিবেশ আর সহজ সরল ভাষা যতো দেখি ততোই মুগ্ধ হই। নতুন কোনো ধারাবাহিক তৈরি কোরে আমাদের উপহার দেন ওপেক্ষায় আছি।',
#  'নাটকে অস্থির হইছে',
#  'নাটকটি অনেক ভালো লেগেছে।',
#  'পোরানো নাটক আমার অনেক ভালো লগে',
#  'ফজা ভাই মঝা মারছে, চনচল চৌধুরী বলেই  কথা',
#  'আই লাইক চঞ্চল চৌধুরী অভিনয়',
#  'অসাধারন.!......',
#  'আমিও সবার সাথে দেখা শুরু করলাম।',
#  'খুবই সুন্দর হাসান ভাই অসাধারন??',
#  'এই নাটকগুলোর প্রতি বিশেষ টান আছে। আখম হাসান, চঞ্চল,মোশাররফ করিম গ্রামের চরিত্রে অসাধারণ',
#  '৯ বছর পর আবার দেখলাম নাটক টা',
#  'অসম্ভব সুন্দর',
#  'ফখরুদ্দীন - ম\u200cঈন\u200cউদ্দীন আমলের নাটক নাকি ? .... <br> এতদিন পর এসে আপলোড দে\u200cওয়ার সাহস হলো ।',
#  'পুরাতন নাটকগুলী আমরা পছন্দ করি এগুলা তুলে ধরবেন নতুন করে ধন্যবাদ',
#  'সালাউদ্দিন লাভলু ভাই এর নাটক খারাপ হয় কি করে....',
#  'অনেক ভালো লাগলো,,,,,',
#  'সুন্দর নাটক সেরা অভিনেতা চঞ্চল চৌধুরী ও সুন্দর অভিনয় করেছে আখম হাসান',
#  '২০০৭ সালে তত্ত্বাবধারক সরকার ক্ষমতায় আসার পর, দুর্নীতি বিরোধী ব্যাপক অভিযান হয়। মুলত এই ঘটনা কেন্দ্র করে এই নাটকটি তৈরি হয়েছিল',
#  'পরির কথা গুলি অনেক ভালো লাগে',
#  'ছলনাময়ী পরি মতিকে ঠকিয়েছে',
#  'এই নাটকটা দেখার পর লাঠিয়াল গ্রাম নাটকের কথা খুব মনে পড়ে গেলো',
#  'মনসুর সাবিনা কে একটা থাপ্পর দিলে নাটক  সুন্দর হতো,,,আর তার ভাই তো নেই তার ভাবিকে সবাই মিলে মনসুরের কাছে বিয়ে দিলে নাটক টা আরো সুন্দর হতো,,যদি তার ভাই না আসে,নাকি মারা গেছে সব জাচাই করে এটা করার দরকার ছিলো',
#  'সাবিনার মতো মেয়ে যেই ছেলে বিয়ে করবে,সেই ই মরবে,,,,অনেক পাকনা ছেরিডায়',
#  'সাবিনার সব গুলা নাটক খুব ভালো লাগে,তার হাসি তার আকা বাকা অভিনয়,তার কথার ইসটাইল,অনেক সুন্দর,লড়াই নাটকে সে খুব ভালো অভিনয় করছে আখম হাসানের সাথে,কিন্তু একটা কষ্ট পেলাম আখম হাসান কে সে শেষের দিক দিয়ে অনেক অপমান ও মাইর খাওয়াইছে,,,,,লড়াইয়ে তাদের ভালো বাসার জুটিটা অনেক সুন্দর ছিলো,,,',
#  'গ্রাম বাংলার নাটক অনেক ভালো লাগে',
#  'নাটকটা জোশ',
#  'অসাধারণ... <br>অনেক অনেক সুন্দর...সবাইকে ধন্যবাদ সুন্দর অভিনয়ের জন্য ৷বিশেষভাবে গায়ের ছেলে পরোপকারী নিলয় ভাই , লিজা ও তার বাবার অভিনয় ৷আর গোলম ফরিদা ছন্দা আমার ভীষন প্রিয় পছন্দের এক অভিনেত্রী ৷ সবশেষে পরিচালককে ধন্যবাদ সুন্দর একটি নাটক উপহার দেয়ার জন্য ৷',
#  'ওরা কোন ধরনের মানুষ বুঝলাম না পানি খাওটাও আধব রক্ষা করে খেতে পারেনা  দাঁড়িয়ে দাঁড়িয়ে পানি খাই 🤔🤔🤔🤔🤔',
#  'নিলয়ে ওবিনয়  বিসন ভালো লাগে',
#  'অসাধারণ নাটক',
#  'সাবিনার বাড়িটা হলো মোশারফ করিমের বাড়ি',
#  '👍👍👍👍👍',
#  'অসাধারণ একটা নাটক।',
#  'আলহামদুলিল্লাহ এটা ভালো কাজ',
#  'নাটক টা আমি তিন বার দেখছি ভালো লাখছি',
#  'ভাই  আপনাকে  কি বলে যে ধন্যবাদ  দিবো ভাসা হারিয়ে ফেলেছি।',
#  'মেয়ে টা নাটকে বেদব চরিত্রে অভিনয় করেছেন',
#  'অসাধারণ  ভাই,  শান্তি  পািইলাম।',
#  'রাগারাগি  অনু অনু করে এক সময়  অনুরাগের  সৃষ্টি  হয তারই প্রকৃষ্ট প্রমান মনসুর  এবং সাবিনা। নয কি?',
#  'শেষের ছিনটা নাইস হয়ছে',
#  'সুন্দর একটা মাটির গন্ধ মাখানো রাগ অনুরাগে ভরা মন ভরানো নাটক দেখলাম।এই নাটকের সকলকে অজশ্র ধন\u200d্যবাদ।',
#  'লাঠিয়া গ্রামের বাড়িটা হলো মুনছুরের বাড়ি',
#  '💚💚💚💚💚',
#  '💝💝💝💝💝',
#  '💞💞💞💞💞💞💞💞💞',
#  'সুপার 💛💛',
#  'দারুণ 💛💛💛',
#  '❤❤❤❤❤❤',
#  'কতো সুন্দর ছিলো আগের নাটকগুলো...<br>না ছিলো কোনো অশ্লীলতা না ছিলো কোনো  বেহায়াপনা....অনেক অনেক ভালো  লাগলো নাটকটা....',
#  'নিলয়, সোনার পাখি রুপার পাখি নাটকে খুব সুন্দর অভিনয় করেছে।।',
#  'অসাধারণ লাগছে সবার অভিনয়। নাটকটিও অনেক সুন্দর ছিলো। জিনিয়াস নির্মাতা ও জিনিয়াস আর্টিস্ট। লোকেশন,  কস্টিউমস এবং চরিত্র সব মিলিয়ে অসাধারণ।',
#  'বাংলালিংক তো ফোন ঢুকবেনা',
#  'নাটক  আমার খুব ভাল লাগলো',
#  'দারুন একটি নাটক',
#  'বেলা বিশ্বাসের বাড়ি বিল্ডিং হওয়ার কথা ছিল বেলা বিশ্বস্ত ইঞ্জিনিয়ার লাগাই ছিল বিল্ডিং করার জন্য এখনো বিল্ডিং হয়নি',
#  'খুব ভালো লাগলো নাটকটা দেখে,,,',
#  'এই নাটকের আরেকটা পর্ব চাই  ভালোই লাগলো নাটকটা দেখতে',
#  'এই প্রথম কাজী শহীদুল ইসলাম এর রচনায় নাটকে পছন্দের মানুষের সাথে মিল হইলো',
#  'সালাউদ্দিন লাভলু ভাইয়ের পরিচালিত নাটক গুলো অনেক সুন্দর 👍❤️<br>সাথে নিলয় ভাইয়ের অভিনয় অনেক সুন্দর 😍',
#  'এই সব নাটক দেখলে মনটা ভরে  যায়,',
#  'আমার মন ছুঁয়ে গেছে এই কাহিনী😍',
#  'ছাবিনা ভাবিকে অনেক কষ্ট দিয়ে কথা বলছেন!',
#  'সালাউদ্দিন লাভলু আসলেই একটা জোস পরিচালক উনার তুলনা হয় না,,, আর সাবিনা বেগম তু পুরাই আস্তির অভিনয় করে,,, অনেক ভালো লাগলো দেখে <br><br>এক কথায় অসাধারণ ❤️❤️❤️❤️',
#  'অনেক ভালো লাগলো',
#  'নিলয় ভাই  কে অনেক ভালো বাঁশী আই লাভ ইউ ভাই',
#  'এতো সুন্দর হয়েছে বলার মত না??',
#  'অনেক সুন্দর',
#  'খুব সুন্দর গল্প বানিয়েছেন...',
#  'ছাবিনার চরিত্র টা একদম জগন্য গ্রামের কুটনী বিশিষ্ট বেহায়া নির্লজ্জ মহিলার চরিত্র ফুটে উঠেছে একদম ফালতু হইচে জা নাইকা হিসেবে বেমানান দেকতেও সুন্দর না ডাইনি ডাইনি চেহারার আর্ট👹 এর আলো নামের মেয়েটাই দেখতে বেষ্ট',
#  'পরিবেশগত নাটক থাকে ভাই পরীর সেক্সি ভিডিও নাটক জামাল উদ্দিন',
#  'অনেক সুন্দর হয়ে নাটকটা',
#  'অসাধারণ। বউ হবার অভিনয়টা।। ওনেক মজার ছিলো',
#  'সাবিনার ঘর কবুলিয়তনামায় আনোয়ারের ঘর ছিল।',
#  'গ্রামগঞ্জ এর নাটক সেই ভাল লাগতাছে',
#  'পরিচালক ও বুঝে কোন মাইয়্যা কোন চরিত্রে দিতে হয়।',
#  'সাবিনার মত মেয়ে যার কপালে জুটবে তার জীবন ত্যানা ত্যানা করে দিবে😂😂😂😂😂',
#  'গোলাম ফরিদা সারিসুরি নাটকে অনেক সুন্দর অভিনয় করছে। <br>তার উপর মা কালির ভর করছিল😂😂😂<br>৪/৭/২০২০',
#  'নিলয়ের বাড়ি টা হল লাঠিয়াল গ্রামের বেলা বিশ্বাস এর বাডি ছিল',
#  'মেয়েটাকে এই নাটকে মানাই নি',
#  'লুঙ্গি পরা স্টাইল আছে',
#  'ভালো লাগলো😀😍',
#  'নাইচ নাটক',
#  'আসলে লিজার প্রথম নাটক,<br>এক কথায় অসাধারণ.......',
#  'নিলয়ের গায়ের নাটক ভালো লাগে।',
#  'ছাবিনা আপু তোমার অভিনয় খুব সুন্দর হয়েছে',
#  'জেই হালার গড়ে হালার কানি লেখছে  তে একটি লিচচা ।মেয়ে ট বানদর ।',
#  'আমার প্রিয় অভিনেতা নিলয় ভাইয়া',
#  'নাটক টা অসাধারণ ছিল',
#  'আমার আগের দিন গুলি মনে পনে পরে গেলো,,,,',
#  'খুব সুন্দর একটা দেখলেই দেখতে ইচ্ছে করে,,,,',
#  'ভাল নাটক,নাই কাটা  অনেক ভাল',
#  'মনমুগ্ধকর নাটক',
#  'শেষ টা দেখতে পেলাম না',
#  'শেষ টা কোথায় আছে',
#  'শেষটা দেখতে চাই',
#  'নায়িকা কে একদম ভালো লাগে নাই',
#  'আমি অপূর্বর সব নাটক দেখার চেষ্টা করি।কিন্তু এ নাটক টা ফালতু লাগল।',
#  'যেখানে একটা সম্পর্ক দু- ভাগ হয়ে গেছে,সেখানে একটা কাগজ টুকরো হয়ে যাওয়া',
#  '🥵🥵🥵🤧🤮🤮🤮🤮🤮🤮🦧🦍🎌😡😡😡😡😡😡😡🤬💨💨💨💨💨👎👎👎👎👎👎🤏👎👎👎',
#  '💓💓💕💕❤💛🧡🧡💛❤💕💓💐💐',
#  'তাহলে আমার কি কর্তব্য ?  আমাকে না নিয়ে আমার বউ কোথাও যায়না ৷ অর্থাৎ, বউতে আমি, আমাতে বউ ---  ঐ মুক্তার মাঝে শুক্তির মতো আরকি । এরূপ ক্ষেত্রে বিচ্ছেদের নিয়মাবলী, বিচ্ছেদ - পরবর্তী মিলনলীলার গাইডবুক বাংলাদেশে প্রকাশিত হয়ে গেছে ? সম্ভবত হয়নি, কারণ হলে আমার বউ তার একটা কপি আনিয়ে আমাকে দিয়ে রোজ একপাতা করে কপি করাতো ৷........',
#  'অসাধারণ',
#  'চয়নিকা দিদি, অসাধারণ পরিচালক। অভিনয় ও অসাধারণ সবারই। পুরো নাটক টা দেখতে পেলাম না, এটাই খারাপ লাগল।',
#  'এই ভাবে নাটক শেষ করার কি কারণ... বুঝলাম না...???',
#  '২ পর্ব চাই',
#  'অপূর্ব স্মাট একজন অভিনেতা (কলকাতা)',
#  'চয়নিকা চৌধুরী কে অসংখ্য ধন্যবাদ এই রকম একটা নাটক উপস্থাপন করার জন্য ।',
#  'রাখি অভিনয়ে নিয়মিত হলে ভাল হোত',
#  'শেষ টা কাটা কেনো?',
#  'এক\u200cটি নাটকে ও ভালো করে মিল দিতে পারেনা<br>গাজাখোর পরিচালক শুরু টা সুন্দর করে শেষটা মিলাতে পারেনা এই দুজনের তিনটি নাটক দেখলাম এক\u200cটির ও মিল নেই',
#  'সব শাশুড়ি যদি এমন হতো তাহলে ছেলেরা কখনো যা ইচ্ছে তাই করতে পারতোনা।',
#  'অমীমাংসিত ভাবে নাটকের সমাপ্তি ।একদম ভালো হলো না।',
#  'চয়নিকা চৌধুরী নাটক অনেক ভালো লাগে ভালো একটা পরিচালক বাংলাদেশে',
#  'দুই বছর আগে কমেন্ট করেছিলাম নাটকটা কেন অসম্পূর্ণ!!! আজও দ্বিতীয় পর্ব পেলাম না!!!!!',
#  'কোথায় যে গেলে রাখি আফু আমার পেবারেট নায়িকা।',
#  'আমার খুব ভালো লাগে অপূর্ব নাটক,<br>দেখছি প্রবাসী মালয়েইশিয়া, থাকলে কাছে কে <br>আর বোঝে,হারিয়ে গেলে তবেই খোঁজে,,?',
#  'অনেক ভালোবাসার সম্পর্ক এবং সাংসারিক সম্পর্ক ইগো এবং রাগে কারনে বন্ধন ধ্বংস হয়ে যায় আসুন আমরা সবাই ইগো এবং রাগ কে পরিহার করে চলি',
#  'আমার বউ যদি আমার মাকে এভাবে আদর করতো,,,বিশ্বাস করুন,,,সমস্ত পৃথিবী দিয়ে সেই মেয়েটাকে ভালবাসতাম,,,,,কিন্তু এমন একটা বউ পেয়েছি,,,,,জীবনটা ছাড়খার হয়ে গেছে',
#  'একটা যিনার স্বীকৃতি দেওয়া হইছে!',
#  'সুন্দর অসাধারণ',
#  'বাকিটা কই 😡😡😡',
#  '💘💞💘অপূর্ব ভাইকে ভালোবেসে থাকলে লাইক চাই,,,💘💞💘',
#  'এটি একটি ফালতু নাটক নাটকের  কোন মিল নাই',
#  'নাটকটি অসম্পূর্ণ রয়ে গেছে।<br>আর ডিভোর্সের ব্যাপারে রাইটার অজ্ঞ।',
#  'ডিভসের পরে কোন মেয়ে সাম্মী বাড়ি যায়<br>এটা কোন কান্ড রে বাবা',
#  'ঐ মেয়ে চলে গেলে, আরেকটা বউ পাবি',
#  'অপুর্ব আছে তাই, ভালো লাগলো',
#  'যন্ত্রমানব।দুঃখিত, অপূর্বের মতো একজন অভিনেতা অন্ততঃ এই নাটকে অভিনয় করায়।যে ভূমিকায় অভিনয় করেছেন  তা অত্যন্ত নিন্দনীয়।',
#  'ইসলাম ধর্মের মানুসদের জন্মদিন পালন করা জায়না এটা নাজায়েজ',
#  'চয়নিকা চৌধুরী মানেই এক নতুন কিছু পাওয়া।',
#  'নাইচ',
#  'নাটক দেখা বন্ধ করে দিলাম,কারন অপুর্ব এর পাশে একটা অপুর্ব নায়িকার দরকার ছিল।',
#  'অপূর্ব আর মেহজাবিন ছাড়া এ ধরনের নাটক ভালো লাগেনা।',
#  'মেহজাবিন আপু আপনাকে চিনা জাচ্ছে না',
#  'মেহজাবিনকে সাধারণ মেকআপেই সুন্দর লাগে।',
#  'মেহজাবিনের ফেস এর সাথে চুল গুলো বেমানান লাগছে।',
#  'চোখ দিয়ে পানি বের হয়ে আসলো সুন্দর অভিনয়',
#  'সোমায়া সিমু পছায়',
#  'অনেক ভালো লাগলো নাটক টা দেখে সত্যি দারুণ। সজল ভাই আর মেহেজাবিন আমার খুব পছন্দের।',
#  '💞',
#  'নাইচ',
#  'সজল/ মেহজাবিন অসাধারন👌👌👌💜💜💜',
#  'মেহেজাবির হেযার স্টাইল খুব খারাপ  লাগল  কোলকাতার',
#  'লাস্টে ছকের পানি দরে রাকতে পারলান না বেরী নায়চ নাটক',
#  'যে শাড়ী টা আপু কে গিফট করেছে এই টা আপু পড়লে আরও অনেক ভালো হতো',
#  'আপুর চোখ দুটো আমার অনেক ভালো লাগলো',
#  'মায়েদের কুসংস্কার ত্যাগ উচিৎ, ছেলের পছন্দেই সব কিছু হওয়া প্রয়োজন! উভয়ের অভিনয় ভাল হয়েছে।',
#  'হুম ভালো লাগার মতো ফিল্ম',
#  'দারুন নাটক',
#  'আমি সবসময় মেহজাবিনের নাটক দেখি জদি তার নাম্বারটা পাইতাম কথা বলার ইচ্ছে ছিল কেউকি দিবন নাম্বটা।',
#  'সজলের অভিনয় ভালো হয়েছে।',
#  'মেহজাবিন কে একদম সুচিত্রা সেনের মতো লাগছে।',
#  'নাটক: ব্লাইন্ড লাভ<br><br>পরিচালনা :  ইঞ্জি: এম.জামান<br><br>সাধারণ নিয়মে অফিসে কাজ করতে, করতে একজন উচ্চ পদস্থ কর্মরত যুবকের ভালো লেগে যায়  তাঁর সঙ্গে এক সাথে কাজ করছেন একজন সুন্দরী, শান্ত, কর্ম দক্ষ ,বুদ্ধিমতি ,মিষ্টি মেয়েকে।মেয়েটির অনেক গুনের মধ্যে তার সমাজের চোখে দোষ ছিল যে সে দুর্ঘটনায় তার প্রাক্তন স্বামীকে হারায়।কিন্তু যুবক ইফাত তার মনের গহিনে সামায়াকে বরণ করে নেয় তার রূপে, গুনে, বুদ্ধিমত্তার কারণে।ইফাতের বাবা মা প্রথমে সামায়াকে মানতে না পারলেও অবশেষে তাকে পুত্রবধূ হিসেবে মেনে নেন।<br>আমার গল্প ফুরালো নটে গাছটা মুরলো। <br><br><br>গল্পের অসাধারণত্য ছিল নায়ক ইফাতের ভূমিকায় সজলের অভিনয়। ইফাতের চরিত্রে সজল ভালোবাসায় যত গভীর ছিলেন, অনুরাগে যত বিভোর ছিলেন, ভালোবাসা হারানোর যন্ত্রণায় ,বেদনায় ততটাই মর্মাহত ও কাতর ছিলেন। এই সম্পূর্ণ আবেগ, আবেশের সাবলীল বহিঃপ্রকাশ আমরা পাই সজলের চোখের অভিনয়ে ও অভিব্যক্তিতে।সজলের বিভিন্ন আবেগের অনায়াস অভিনয় আমাদের স্তব্ধ করে।সাধারণ নাটক সজলের অভিনয়ের নিষ্ঠা ও গুনে হয়ে ওঠে অসাধারণ। <br><br>সুদেষ্ণা শূর, কলকাতা, পশ্চিমবঙ্গ।',
#  'মেহেজাবিন আপু অনেক সুন্দর হয়েছে নাটকটা আর তোমাকে অনেক ভালো লাগছে',
#  'অামি এই দুজনের জুটি খুব পছন্দ  করি। এই দুজনের নাটক দেখতে অামার অনেক ভালো লাগে।',
#  'অসাধারণ নাটক',
#  'তাই',
#  'সেই মেহজাবিন আজকে সুপারস্টার সেরা নাটক অভিনেত্রী বর্তমান সময়ে।',
#  'বাস্তবে মেহজাবিন আপু খুব সুন্দর',
#  'বর্তমান সময়ে সেরা সুন্দরী সেরা জনপ্রিয় নাটক অভিনেত্রী মেহজাবিন আপুর নাটক দেখি।',
#  'কতা',
#  'মিষ্টি মেয়ে মেহজাবিন। আগে ছিল সুমাইয়া শীমু।',
#  'মেকআপ খুব খারাপ হয়েছে।',
#  'খুব অসাধারণ  লাগলো নাটকটি ?',
#  'চলে, মোটামুটি',
#  'সব কিছু মিলিয়ে ফাইন ।',
#  'ভালই লাগল',
#  'অফিসের ভিতর এমন প্রেম ভালোবাসা নিবেদন ভাল লাগে না........... অফিসের বস্ তো এমন হবে কেন....... যেখানে কাজের জায়গা....... এই সরলাতা কেন জানি অপ্রিয়জনীয় মনে হয়.......!!!',
#  'নাইচ  নাইচ   নাইচ',
#  'অনেক অনেক সুমদর',
#  'বিউটিফুল',
#  'আমি তোমার জন্য হয়েছি শন্যাসী?',
#  'মেহেজাবিন,ইজ গুড লুকিং, নাইচ এভাবে দেখে ভালো লাগছে,নতুন ভাবে দেখে ভালো লাগলো।',
#  'অনেক সুন্দর লাগে ছে নাটোক টা তবে একটা কথা এবাভে সবার পাশে দারাত সোখ পাওয়া মেয়েদের গৃনার  ভোক করতে হতনা',
#  'যাকেই নিন, পরীমণিকে নেবেন না ৷ ও মদ খায়, ....এমা !! ও মদ খায় !!...মদ আমিও খাই, কিন্তু আমি তো পরীমণি নই .......আমি সোনামনি ৷',
#  'মাহফুজ কি অসাধারণ সুন্দর তুমি!!!!!  <br> ❤️❤️️তোমাকে খুব ভালো লাগে।  তোমার শত শত নাটক দেখেছি আমি, কিন্তু কোনদিন কমেন্ট করি নাই। মন চায় তোমায় দেখি আর দেখি💞💞',
#  'মাহফুজ ভাই এর নাটক এর কৌশ্ল অসাধারণ৷ যে কোন মেয়েই তাকে ভালো বাসবে৷ অসাধারণ নাটক',
#  'যে কোন মেয়ে তাকে পছন্দ করবে',
#  'মাফুজ এমন নায়ক দেখলে ভালোবাসতে মন চাই',
#  'পাগলি',
#  'আমার কাছে ভালো লাগে নিই',
#  'মাহফুজ আহমেদ বস নাটক কথা কিছু বলা  নেই অসাধারণ',
#  'অসাধারণ নাটক',
#  'চমৎকার লাগলো',
#  'মাফুজ ভাই মানে অসাধারন',
#  'এই সব নাটকে বোন বনের শত্রু হয়',
#  '৭ বছর পর আবার দেখলাম',
#  '৬ বছর পর আবার দেখলাম ...। অনেক অনেক ভাল্লাগছে নাটকটি তাই ৬বছর পর আবারও ফিরে দেখা..।',
#  'মিষ্টি ভালোবাসার গল্প। সজল, বিন্দু, দুজনেরই অভিব্যক্তি দেখার মতো।',
#  'জীবনটা সজলের এই নাটবের প্রথমাংশের<br> মতই রয়ে গেল',
#  'ভাল',
#  'আপু তোমার ভুরুটা অনেক সুন্দর',
#  'সেসের কহিনিটা ওনেক ভাল  লাগল',
#  'ভালো লাগলো।',
#  'খানকির পুলা মিউজিকের কারুনে কিচ্চু    <br>বুজা জায়না',
#  'ভাল লেগেছে',
#  'অনেক সোন্ধর হয়েছে',
#  'নাইচ',
#  'অনেক ভালো লাগলো।',
#  'বাংলাদেশের নাটক যত সুন্দর, ততটাই জঘন্য কোলকাতার সিরিয়াল, কোলকাতার সিনেমা যতটা অসাধারণ, ততটাই অখাদ্য বাংলাদেশের সিনেমা। কিন্তু নায়িকা পেনসিলভানিয়া কে প\u200d্যানসিলভানিয়া বলছে।',
#  'কি দারুন বিবাহ। তার চেয়ে ভাল তাদের যে  ভালবাসা।',
#  'প্রয় এক\u200cই রকম গল্পের আর একটি নাটক মোষারফ করিম করেছেন।।',
#  'ওয়াও অসাধারণ',
#  'মুশারফ করিম আপনার অভিনয় খুবই ভালো। নাটক টি এতটাই ভালো লাগলো আপনাকে বুঝিয়ে বলতে পারবো না।',
#  'বিরক্তিকর মিউজিক 😡',
#  'নাটকটি খুব উপভোগ করলাম',
#  'নাটক টি দেখে খুব খারাপ লাগলো কিছু বলার নেই ,।',
#  'নাটকের ভিতর দর্শকদের একটা চাহিদা থাকে,,সেইটা না পেলে নাটক হয় ফালতু এটাও সেই রকমই মনে হলো।',
#  'সমাজে এ রকম কোট টাই পরা অনেক ভদ্র লোক আছে যারা প্রতিনিয়ত সহজ সরল ভালো মানুষ দের সঙ্গে এভাবেই প্রতারনা করে যাচ্ছে,এদের থেকে সাবধান হোওয়া এখনি সময়।',
#  'অপরাধিদের শাস্তি হওয়া উচিত ছিল।',
#  'মেয়ে মানেই বাটপার,,, প্রতারক,,, বেঈমান,,,,ওদের চোখের পানি বিশ্বাস করা আর মরা গাছে ফুল ফুটছে বিশ্বাস করা সমান কথা',
#  'অসাধারণ ❤❤',
#  'ভাল লাগল',
#  'এমন আবেগঅলা বেডারা এমনি মারা খায়',
#  'খুব সুন্দর লাগছে',
#  'অসাধারণ একটি নাটক',
#  '🎹☎🍈🍈🍒🍔🍢🏹',
#  'বাঁধন আপু সত্যি অসাধারণ অভিনেত্রী',
#  '🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩',
#  'বেশ্যা একটি গালি<br><br>কিন্তু বেশ্যা চরিত্রটা কি খুব খারাপ ?<br>অর্থের বিনিময়ে যে দেহ বেচে সে বেশ্যা।<br>অর্থের বিনিময়ে যে নৈতিকতা বেচে সেও বেশ্যা।<br>অর্থের বিনিময়ে যে ফাইলে সই করে সেও বেশ্যা।<br>অর্থের বিনিময়ে যে চাকুরিতে নিয়োগ দেয় সেও বেশ্যা।<br>অর্থের বিনিময়ে যে আসামীকে জামিন দেয় সেও বেশ্যা।<br>অর্থের বিনিময়ে যে দলের পদ বেচে সেও বেশ্যা।<br>অর্থের বিনিময়ে যে ঠিকাধারীর কাজ বেচে সেও বেশ্যা।<br>অর্থের বিনিময়ে যে নমিনেশন বেচে সেও বেশ্যা।<br>অর্থের বিনিময়ে যে কলম বেচে সেও বেশ্যা।<br>তবে যার বেচার মত অবশিষ্ট আর কিছু থাকেনা<br>সেই শুধু দেহ বেঁচে দেয়। <br><br>✍️লেখক মিরাজুল ইসলাম। ✍️',
#  'মোশারফ করিম এর সব নাটক আমার ভালো লাগে।',
#  'এগুলা সব বিয়ের নামে প্রতারণা আমি প্রথমে দেখেই বুঝেছিলাম।নাটকে তো মিল হয় শেষে, কিন্তু,বাস্তবে তা ঘটে না',
#  'বাধন,মোশারপ,করিম,নাটক,দেখতে,চাই,তাও,নতুন,নাটক,এই,দুইজন,খুব,সুইট,বাধনের,হাসি,টা,খুব,সুইট',
#  'মোশারপ,করিম,বাধন,আমার,সেরা,নায়ক,নায়িকা,',
#  'প্রেমটা এমন হৱাই জরুরী',
#  'মোশারফ ভাই আপনি ও অভিনেত্রী আমাদের উত্তম সূচিত্রা । হলিউড  দরকার নেই । হলিউড আমাদের দেখবে । । এর মধ্যে হিন্দি ঢোকাবেন না । পার্থেনিয়ামের মতো সব ধংস করে ফেলবে আপনাদের সম্পদশালী বাংলা ঐতিহ্য । কথায় কথায় মুম্বাই, হিন্দি উল্লেখ একদিন খেয়ে ফেলবে পশ্চিমবঙ্গের বাংলার মতো । সম্পদশালী হয়েও  নিজেদের ছোট ভাবছেন কেন ? এতে তো পরবর্তী বাঙালি জেনারেশন হীনমন\u200d্যতায় ভূগবে',
#  'সেরা নাটক....!!!',
#  'অসাধারণ',
#  'কি বলবো ভাষা হরিয়ে ফেলেছি! অসাধারন নাটক',
#  'নায়াকে চোদার জন্য বালো চোদার মেয়ে',
#  'পাগল ছাগল মোশারফ এদের দিয়ে নাটক করাই, নাটকের মান সম\u200d্যান আছে এদের কারনে।',
#  'মোশারফ শালা আসলে একটা বলদ, শালা পাগল চাগল।',
#  'আজমিরি হক বাধন',
#  'সুন্দর স্ক্রিপ্ট।',
#  'তার মানে বুঝা গেল ঢাকার  মেয়েদের দাম কম এটাই সত্য কথা,',
#  'থাপর টাতে মন্টা ভরে গেল উফফ',
#  'পর',
#  'সাহানা তুমি কেমন আছ৷ ০১৯৩৩০০২৩৪৯',
#  'ভালো ছিল নাটকটি।',
#  'নাটকেই সম্ভব।',
#  'সেস অবদী মোসারফকরিম দই না পেলেও ঘোল পেলো আপনার আমার কিন্তু তাও জুটবেনা মনে রাখতে হবে',
#  'মন্দটা মন্দই থাকে যতক্ষণ না তার ভেতরে ভালোটা প্রবেশ করে ।।',
#  'আমার লাইফের সেম ঘটনা',
#  'বস     সেরা',
#  'মোসারফ আসলে নেচারল',
#  'খুব ভালো',
#  'মোশারফ করিম ভাই অভিনয় অসাধারন',
#  'কি বলব ভাষাই হারিয়ে ফেলেছি',
#  '😂😁🤣😀😎😋😇😘😍😐😶😅😅😴🤡🤪🤪🤪👺👹😈👩👰',
#  '🈲',
#  'সত্যি, আখম হোসেন দারুন দারুন অভিনেতা',
#  '🤣🤣😂😂😍😍😜😜😜',
#  'আ,খ,ম, হাসান 😁😁😁😂😂😂😘😘😘😭😭😭😉😉😉🙄🙄🙄❤️❤️❤️👍👍👍।',
#  'ঈধ মোবারক পরিছালক  ভাই সাসুরি এবং ভর মেয়ে টিক আাছে এই নাটক ভাস্তবে কিচু মিল আাছে  ধন্য বাদ  আগের বেকা বাইরার পরিচালক আসলে সে নাটক দেকেনা আগে দেকুন   পরে নাটক বানান , টিক, আছে,ভাই',
#  'অসাদারন',
#  'মনোমুগ্ধকর ❤️❤️',
#  '💖💖💖ঈদ মোবারক অ ক ম হাসান ভাইয়ের নতুন নাটক চাই🇧🇩🇧🇩🇧🇩',
#  'বড় বোনের কথা অনেক ভালো লগে',
#  'বড় আপার কথা খুব ভালো লাগে ❤️',
#  'অসাধারণ এই নাটক আমি যতবার দেখী ততবার দেখতে ইচ্ছা করে তবুও মন ভরে না',
#  '🐮🐮🐮',
#  'অামার প্রিয় অভীনেএী',
#  'বেন ওয়ালে থাপ্পড় মারা ঠিক হয়নি',
#  'আমার ফেভারিট এক্টর আ খ ম হাসান',
#  'খুব সুন্দর হয়েছে নাটক',
#  'খুবই সুন্দর হয়েছে নাটকটি',
#  'ভালো না',
#  'বাংলাদেশের নাটক আমার খুব ভালো লাগে। আখম হাসান হলে তো কথাই নেই।',
#  'আখম হাসান ভাই কে নিয়ে,,,,, রাতে  শুয়ে শুয়ে,,,,, অনেক গবেষণা করেছি,,,,,মালটা যে কি তা এখনো বুঝতেই পারলাম না,,,, 🇧🇩🇧🇩',
#  'ওয়ান পিস মেড কারিগর ডেড',
#  '🤓🤓🤓🤓🤓🤓🤓🤓',
#  'রবিন্দসঙ্গীত টা যে গাইলেন এটা কোন শিল্পীর গান.কারো জানা থাকলে জানাবেন।',
#  'এ্যানি বেশি চিল্লাচিল্লি করে কথা বলে',
#  'আমার প্রিয় অভিনেত্রী এ্যানি খান।',
#  'এমন বেকা মানুষ আসলে আছেও🤣😂',
#  'দেখার পরে জানাবেন কেমন হয়েছে  নাটকটা প্লিজ',
#  'আখম হাসান এর অভিনয়,,,অনেক ভালো লাগে।।।',
#  'তোর ছবি দেখেই আমার মন ভালো হয়ে যায়,<br>তাহলে তোকে পেলে কতটা আনন্দে থাকবো<br>তা ভাষায় প্রকাশ করা সম্ভব নয়।',
#  'এ্যানি খান এই মেয়েটি অভিনয় অনেক ভালো লাগে।',
#  'আমি বল তারা',
#  'আখম হাসান মানেই অন্যরকম',
#  'দারুণ লাগলো',
#  'ভালো লেগেছে।',
#  'আমারে খুব ভালো লাগছে',
#  '❤❤❤',
#  '&quot;  ভালো !  বেশ  ভালো  একটি<br>   শিক্ষামূলক  হাসির  নাটক । <br>   আ খ ম হাসান  !   লা  জবাব । <br>  আর  সকলে  যথাযথ  । <br>  ধন্যবাদ   প্রডাকশনের  সকলকে । &quot;',
#  'আমাদের নারায়ণগঞ্জ এলাকার আখম হাসান ভাই তার অভিনয় যাদের পছন্দ তাদের লাইক চাই 👍👍👍👍👍',
#  'বুইরা বেটা বউ রে ডাকে <br>টুনটুনি, সোনা মনি 😅',
#  'আ খ ম হাসানের অভিনয় ভালো তবে কিছু কিছু নাটকে এত বেয়াদব পাট নেয় যে দেখতে বিরক্ত লাগে আর এটা এরকম ই একটা নাটক।',
#  'সাবাই ভালো আছেন।',
#  '🤣🤣',
#  'অসংখ্য ধন্যবাদ',
#  '😂😂😂😂😂😂',
#  'নাটকটা বাস্তব এর সাথে অনেক মিল আছে',
#  'এনি আপু আপনাকে একটা কথা বলছি আপনি যদি সিনেমার নায়িকা হন ভালো হবে তবে',
#  'এনি আপুর অভিনয় আমার অনেক ভালো লাগে আর এনি আপুর চেহারাটা অনেক সুন্দর।',
#  'দারুন লাগলো দেখে',
#  'সস্তা সব ডায়লগ',
#  'ফাউল',
#  '❤️❤️❤️',
#  'অপূর্ব র কোন বাছবিচার  নেই,  মেয়ে  পেলেই তাকে চাই!',
#  'বালাম ওই সময়ের হিট সিঙ্গার ছিলো।<br>মুন্সিগঞ্জের গর্ব🖤',
#  'এটা কত সালের নাটক???',
#  'অসাধারণ। বালাম চমৎকার অভিনয় করেছ',
#  '💋💋আমার পিয় নারিকা শাব্নতির💋💋',
#  'কোথায় হারিয়ে গেল শ্রাবন্তী?',
#  'আমার ভালবাসার সঙ্গি এই গান এবং ভগবানের অশেষ কৃপায় আমার ভালবাসার মানুষও আজ আমার কাছে 💖💖',
#  'সুন্দর।',
#  'সম্ভবত ২০০৯ সালের নাটক।',
#  'বালাম না কি',
#  'সেই ছিলো নাটকটি❤️❤️❤️',
#  'অসাধারণ',
#  'যাহা চাই তাহা পাইনা, যাহা পাই তাহা চাই না,কল্পনার জগৎ থেকে সময়মতো বেড়িয়ে   যারা আসতে পারবে তারাই সুখি হবে।',
#  '@@@@@@@@@@@@@@@',
#  'বস সবার সেরার সেরা!  নাটক জগতে নাম নিলে অপূর্ব নামটা অাশে',
#  'ফালতু নাটক আমার জীবন থেকে,৪৩ঃ৫০ চলে গেল,,,ফিরিয়ে দিন,,,এসব ফালতু কু থেকে জে আসে জানিনা,,,ফাটা,বাশের মত কন্ঠ মেয়েটার।',
#  'শ্রাবন্তী অভিনয়ত নাটক আমি পারবো না কিছুতেই তোমাকে ভুলে যেতে।<br>নাটক টি আপলোড দিবেন,',
#  'অনেক মিস করি চয়নিকা আপুর নাটক,',
#  'বালামের নাকানাকি গান একধুম বাজে লাগে',
#  'শ্রাবন্তীকে দেখলে আমি তার জন্য পাগল হয়ে যায় ।তাকে আমার এত ভালো লাগে কি করে বোঝায়',
#  'হেব্বি লাগছে নাটক টা আমার অপূর্ব',
#  'এত সুন্দর একটা মেয়ে, নিজেকে অভিনয় থেকে সরিয়ে নিল। শ্রাবন্তিকে খুব  মিস করছি।',
#  'সাকিব আল হাসানের বিয়ার পর অনেক কান্নাকাটি করছিলাম, এই নাটকটা দেখে বুঝতে পারছিলাম, তাহারা সেলিব্রেটি😁',
#  'হয়লি কলা কুনো কথা জানিনা হবে কি বলা<br>আমার মনের কথা অনেক কথা জমে<br>আছে আইলাভ😍😍',
#  'চয়নিকা চৌধুরী আপনাকে ধন্যবাদ এই নাটকের জন্য ।',
#  'ভালবাসা এক আবেগ--- ভালবাসার একটা নিদির্ষ্ট রঙ রয়েছে। নীল!!“!“!“!  যেমন আকাশের রঙ নীল। কিন্তু  ভিন্ন কারণে এর রঙ পরির্বতন হয়। কিন্তু তার প্রকৃত রঙ নীলই থাকে। ভালবাসার মানুষের সঙ্গে  পরিস্থিতির জন্য কিছুটা ঝাল, কিছুটা টক বা কিছুটা মিষ্টি----সব মিলিয়ে ভালবাসার অপূর্ব সৃষ্টি। তবে ভালবাসার প্রকৃত স্বাদ  মিষ্টি। সমস্যা হল---ভালবাসার সঙ্গে কিছু মন্দ বা নোংরা স্বার্থ  জড়িত করার  কারণে ----ভালবাসার প্রকৃত স্বাদ অনেকেই পায় না। এটা স্বর্গ হতে আসে। এখন স্বর্গ মহান স্রস্ট্রার পবিত্র স্থান। বিধাতার আইন না মেনে ---ভালবাসার স্বাদ গ্রহণ করতে পারবে না। অবৈধ সম্পর্ক বা ]শাররীক বা মানসিক----কোনটাই সঠিক নহে। তবে কাউকে ভাল লাগতে পারে----তবে বিবাহ করার জন্য। এবং বিবাহ ব্যতিত নির্জন স্থানে এক সঙ্গে আড্ডা পর্যন্ত দেওয়া সম্ভব নহে। পারিবারিক ভাবে বিবাহ করে---তার পর যত পার ভালবাস। এই ভালবাসাতে স্বর্গ  সুখ খুজেঁ পাবে। আর ভালবাসা শুধু  স্বামী/স্ত্রী নহে বা প্রেমিক/প্রেমিকার জন্য নহে। তুমি কারো কষ্ট দেখে পাশে বসে তার কথা শুনে---তার সমস্যার সমাধান সাধ্য অনুযায়ী  করাটাও ভালবাসা। মায়ের জন্য ভালবাসা----বাবার জন্য ভালবাসা----মোট কথা সবার প্রতি মানবিক ব্যবহরাই ভালবাসা। সবার জন্য কল্যাণকর কিছু করাটাও ভালবাসা।----ইত্যাদী',
#  'পাগল চ*** নাটক একটা বানাইছে',
#  'আমার দেখা প্রথম নাটক ছিল।<br>dvd তে দেখছিলাম',
#  'বালাম নিয়ে বেশী বাড়াবাড়ি,,,,, <br>বালাম চাল রেঁধে খাও',
#  'ওল্ড ইজ গোল্ড ❤',
#  'যাকো নাটক টা দেখে অনেক ভালো লাগলো যে অপূর্ব তার ভালোবাসা কথা দিয়ে বুঝিয়ে নিতে পেরেছে 💖আই লাভ💖 অপূর্ব  💖',
#  'খুব ভাল লাগল অপূর্ব সব সময় অপূর্ব 😍😍😍😍😍',
#  'অপূর্ব বেস্ট',
#  'নাটকি যত দেখি ততই ভালোলাগে',
#  'ভালবাসি বালাম কে',
#  'এরকম নাটক দেখতে আমার অনেক ভাল লাগে',
#  'তুমি বদ্ধ উম্মাদ, আমি নয়- আমি আমার স্বপ্ন পথে সে ছোট কাল হতে একা একা চলছি, আমি সম্পূর্ণ নিজের উপর নির্ভরশীল। তবে মহান আল্লাহর উপর আস্তা বা বিশ্বাস ছিল চরম পর্যায়। কারণ  আমি জানি সব কিছু মহান আল্লাহর হস্তে। তাই বাবার উপর পর্যন্ত নির্ভরশীল ছিলাম না। আর খুব একা  অনুভূব হলে আনিলাকে কাল্পনিক সঙ্গী করতাম।তবে কোন প্রকার অপবিত্রতা বা কোন যৌনতার কল্পনা নয়। শুধু চাদেঁর মত ছাড়া হিসেবে  পবিত্র স্বর্গীও পরির মত মনে করে শক্তি সঞ্চয় করতাম। তার বিবাহ বিচ্ছেদের সংবাদ শুনে কিছুটা ধ্বস নেমেছিল বটে তবে পরে নিজকে আগের জাগায় নিয়ে এসছি। বিবাহর পরে পারিবারিক সমস্যার জন্য  কিছুটা হতাশ বা আবেগী হলেও নিজকে আবার পূর্বের স্বপ্নের পথে চালিত করছি। সে স্বপ্নে আমি একা। আর সঙ্গে বিশ্বের সব সৃর্ষ্টি। তবে তোমার ধ্বংস আমাকে কিছুটা কষ্ট দিলে পরে চিন্তা করলাম আমি চেষ্টা করেছি তোমার সঙ্গে দাড়াঁতে কিন্তু তুমি সঙ্গে থাকনি। এবং পরে কিছুটা এড়িয়ে গেছ। এবং অবহেরা করছো এবং আমাকে হারানোর চেষ্টা করছো। তবে কিছুটা সময় আমার প্রতি আন্তরিক ছিলে তাই  কিছুটা  আমি ভাবতে হয়েছে তোমার জন্য। সত্যি তুমি কে????????????  তবে আমার রাজুত্যে আমি একা । কারো উপর নির্ভরশীল নয়। এবং কারো জন্য অপেক্ষা নয়। বরং নিজকে তৈরি করছি বিশ্ব শান্তির জন্য। তবে তোমার মত সু  শিক্ষিত পাগলির প্রয়োজন ছিল সহযোগ িহিসেবে তবে তুমি কিছুটা বেশী পাগলী। ভালো থেক।',
#  'জারা বিয়ার আগে প্রেম করে,তাদের বিয়ার পর আর সেই সুখ থাকে না,আরো যদি হয় এক সাথে প্রেম আর এক সাথে বিয়া,তাহলে তো জীবনি শেষ।',
#  'ভালোবাসা মানুষটা সবাইর কপালে থাকে না ভালোবাসা এরুকুম কেনো বুঝিনা ♥♥♥♥♥',
#  'নিরবে প্রেম',
#  'মামুন',
#  'রাইট সপ্ন কখনো বাস্তব হয় না, সপ্ন তো রাতের আদারে দুই চোখ বন্দ করে দেখে তা কি আর পুরন হবে,সত্যিকার ভালবাসা কয়টা বা পুরন্যতা পায়,,,,,,,,,!!!!',
#  'অপেক্ষার ফল ভালোই হয়। অসাধারণ',
#  'টনি-ডায়েস আর শ্রাবন্তির  নাটকটা চাই<br>যেটা এস ডি রুবেলের একটি অ্যালবাম নিয়ে নাটকটা করা হয়েছে',
#  'মিলে যাই....',
#  'পারছা আর ফারহান এদের আগে খুব ভালো লাগত আর এখন দেখলেই শুরু হয়ে যায় আজাইরা ঝগড়া। বাদ দিয়া দিছি ২ টাকেই',
#  'নাটকের গল্প টাই পছন্দ হলো নাহ এটা কেমন নাটক রে ভাই আজব নাটক আজাইরা গল্প ছেকা খোর গল্প হইলেই কি নাটক সুন্দর হবে বলে মনে করেন তাইলে ভাই এইডা হুদা হাও ভাবনা',
#  'অসাধারণ',
#  'ভালোবাসার আরেক নাম ফারহান ভালোবাসা অবিরাম তোমার জন্য সবসময় তোমার নাটকের ওপেক্ষায় থাকি ভালোবাসা অবিরাম 💖💖💖',
#  '😛🤨',
#  'আমরা বিনোদন এর জন্য নাটক, গান আর অন্য অন্য কিছু দেখিনা কেন আসুন আমরা সবাই নামাজ পড়ি।',
#  'কি বলব ভাসা হারিয়ে পেলেছি😭😭',
#  'ভাই এইটা দেখার পরে অনেক কষ্ট লাগছে😢😢',
#  'যাক নাহ্',
#  'সত্যি অসাধারণ নাটক',
#  'ফারহান ভাইয়া আর পারশা ইভানা আপুর জুটির দেয়ালের অপারে তুমি নাটক টা কে কে দেখেছেন',
#  'অসাধারন একটা নাটক<br>শেষের দিক টা দেখে কান্না চলে আসছে',
#  'শেষটা দেখার জন্য মোটেও প্রস্তুত ছিলাম না।',
#  'ভালোবাসা হায়রে ভালোবাসা।😭😭😭😭😭',
#  'খুব ভালো লাগলো',
#  'গল্পটা অনেক সুন্দর ছিল। অভিনয়ে ফারহান ভাই বলে কথা। খুব ভালো লাগলো।',
#  '💔',
#  'পৃথিবীতে বেচে থাকা জীবন্ত লাশ গুলো যদি অভিযোগ করে ❤️ তাহলে শেষ হয়ে যাবে  অনেক গুলা সংসার 😔',
#  '💜💜',
#  'ভালো নাটকের শেষ টা এমন হয় কেন ?????',
#  'মনে হচ্ছিল আমার গল্পের কিছু অংশ দেখতেছিলাম,,,চোখে পানি চলে আসছে🖤',
#  'গল্পটা সেরা হয়েছে!',
#  'আমার মতো ভিডিও ক্লিপ দেখে নাটক দেখতে কে কে আসছেন।।।।',
#  'ফারহান ভাইয়ের নাটক অসাধারণ হয় কে কে আমার মতো পছন্দ করেন',
#  'ফারহান ভাইয়ের নাটক অসাধারণ হয় কে কে আমার মতো পছন্দ করেন',
#  'অনেকদিন পর একটা সেরা নাটক দেখলাম প্রথম থেকে শেষ পর্যন্ত অসাধারণ ছিলো।',
#  'খুব সুন্দর নাটক টা <br>ভালো লাগছে 🥰',
#  'অসাধারণ 😍😍😰',
#  'কিছু বলার নাই,,,জীবনের গল্পের সাথে মিলে গেছে',
#  'এই না পাওয়ার যন্ত্রণাটা খুবই 😭😭😭😭😭😭😭😭😭',
#  'কমেন্ট বক্সে এত্ত আল্লাহওয়ালা দেখে ভালো লাগল😀',
#  'কিছু কিছু ভালোবাসা এই ভাবে ভেঙ্গে যায় । কিছু ভুল বোঝার কারনে 🥀🥺',
#  'চিঠির লেখাটা শুনে অনেক কান্না আইছে।',
#  'প্রিয় ভাই আপনার ছোট্ট বোনের পাশে একটু দাঁড়ান ,কোরআন তেলাওয়াত গজল এবং আরো অনেক ভিডিও বানাই🙏🙏',
#  'মেসি রোনালদো 🥰',
#  'কথাটা মিথ্যা হলে-ও সত্য,এই গল্পের সাথে অনেকের বাস্তব জীবনের গল্প মিলে যাবে।<br><br>খুবই কষ্ট পেলাম। লাইফে এইসব ইমোশনাল কষ্ট না পেলে বুঝা যায় না,কত যন্তনাদায়ক।',
#  'সত্যি যার প্রিয়জন হারিয়ে গেছে তারাই বোঝে😶 কতটা কষ্ট হয় 🥺 আর চাইলেও যাদের ফিরিয়ে আনা সম্ভব নয় 😭 এই রাগের জন্য অনেক কিছু ঘটে যেতে পারে জীবনে 😔 আর এই রাগের জন্যই কারো কারো প্রিয়জন সেই নীল আকাশের তারা হয়ে যায় আর চাইলেও তাদেরকে আর ফিরিয়ে আনা সম্ভব নয় 😭',
#  'প\u200cরিচালক মহদয়\u200cকে অ\u200cনেক অ\u200cনেক ধন\u200c্যবাদ। এমন একটা নাটক উপহার দেওয়ার জন\u200c্য',
#  'ভালোবাসার মানুষটি কে পাওয়ার সৌভাগ্য সবার হয় না 😊 আর প্রীয়জনদের কখনো অবহেলা করতে হয় না।',
#  'এই সালার নাটক গুল দেখলে আবেগে বুকটা ভরে যায়,,, থ্যাংক্স আ লট ফারহান ভাই,,,😢😢😢',
#  '😶',
#  'অণেকভালো',
#  'ফারহান ভাই অন্ধের অভিনয় টা সত্যি অসাধারণ ছিল।',
#  '❤️❤️❤️❤️❤️',
#  'আলিফ লাম মিম আলহামদুলিল্লাহ ৩০ নেকি হয়ে গেল।',
#  'অসাধারণ 🖤',
#  'ডববডড্',
#  'বালের নাটক, এধরণের নাটক পশু ও করেনা 😏😏',
#  'ফালতু নাটক',
#  'প্রান ফ্রুটোর শর্ট ফিল্ম দেখে এই নাটকটি দেখার অনুপ্রেরনা পেলাম। কিন্তু ৪০ টা মিনিট পুরো নষ্ট',
#  'ফালতু কনসেপ্ট।।',
#  'শুরুটা ভালোই ছিল। কিন্তু নাটকের মোড় এরকম ফালতু একটা বিষয় দিয়ে ঘুরবে তা ভাবতেও পারিনি। এরকম নাটক বানিয়ে সোসাইটিতে কি মেসেজ দেয়া হচ্ছে...!!!! আমি ভীত এমন নাটক দেখে। বাস্তবে কখনই যাতে কারো সাথে এমনটি না ঘটে। খুবই বিপজ্জনক আর ভয়ংকর একটি বিষয় যেটাকে ভালো দেখানো হলো নাটকে... এমন মেয়েকে তো ঘৃণা করা উচিত...',
#  'এই নাটকে দেখার কিছুই নেই। শুধু শুধু সময় নষ্ট হল। ফালতু কোথাকার।',
#  'গল্পটা খুবই খারাপ। ২ দিনের সম্পর্কের কাছে ৬ বছরের সম্পর্ক হার মানলো। এধরনের গল্পে নাটক বানালে তা সমাজে নেতিবাচক প্রভাব ফেলবে। ওই মেয়ে যে ২ দিন পর আর একটা ছেলেকে ভালবাসবে না \xa0তার গ্যারান্টি কি?। ফালতু যত্তসব।',
#  'পুরাই ফালতু কাহিনী, ফালতু সব কারখানা ফালতু \xa0ফালতু খামাখা ৩৯ মিনিট নষ্ট করলাম।',
#  'সব ভালোবাস যদি পূর্ণতা পেতো তাহলে আজ কাল ভালোবাসা হারিয়ে যেতো না।',
#  'খুব সুন্দর হয়েছে',
#  'অভিনন্দন',
#  'শাওন আস্তে আস্তে এগুচ্ছে, অভিনন্দন।',
#  'বাটপার- কাউকে ধোকা দেওয়ার আগে নিজের কথা দুই  মিনিট ভাবুন আর কাউকে ভূল বুঝে দূরে ঠেলে দিবেন না।',
#  'শাওন ভাই নাটক দেখতে ভালোই লাগে',
#  'অসাধারণ',
#  '🥰🥰🥰🥰🥰',
#  'শাওন আমার পছন্দের নায়ক',
#  'নাটকটা অরদেক দেখে শেষ করে দিলাম',
#  'অন্য রকম ভালবাসার গল্প, খুবই সুন্দর হইছে',
#  'খুব ভালো লাগলো নাটক টা',
#  'নাটকের মিউজিক গুলা শেই লাগছে❤️',
#  'শামস ভাইর নতুন গান ছাই',
#  '১৭৯৫.বাংলাদেশী নাটকের ভক্ত।',
#  'বাজেট বাড়ান কম খরচে নাটক ভালো হয় না বস',
#  'বাংলা মুভির চেয়ে বাংলা নাটক কার কার ভালো লাগে?',
#  'শাওন ভাইয়ের অভিনয় কার কার ভালো লাগে!',
#  'আসলেই পরিচালক প্রীতি দত্ত ভাই হচ্ছেন একজন জনপ্রিয় জাঁদরেল পারফেক্ট অনেস্ট পারদর্শী পারফরম্যান্স দ্বারা অসম্ভব সুন্দর মনের ভালোবাসার পরিচালক ধন্যবাদ 💜🤎🖤',
#  'সত্যি অসাধারণ চরিত্রে দুর্দান্ত গল্পের দারুন অস্থির অভিনয় দেখে সত্যি মনটা ভরে গেল এবং সায়েদ জামান শাওন ভাই ও নাবিলা ইসলাম আপু দুই জনের স্মার্ট নেস দেখে সত্যি মুগ্ধ হলাম ধন্যবাদ 💜🤎🖤',
#  'অসাধারণ এক্সিলেন্স টেলেন্ট কেমিস্ট্রি গভীর চরিত্রে ভূমিকায় সায়েদ জামান শাওন ভাই ও নাবিলা ইসলাম আপু দুই জনে একদম ফাটিয়ে রোমান্টিক অভিনয় করেছেন এবং দুর্দান্ত পারফরম্যান্স দ্বারা অভিনয় দেখে আসলেই ভালো লাগলো ধন্যবাদ 💜🤎🖤',
#  'সায়েদ জামান শাওন ভাই ও নাবিলা ইসলাম আপু আপনাদের দুজনের জুটির জন্য অধীর আগ্রহ ভালোবাসা কিংবদন্তি হৃদয় ছোঁয়া অফুরন্ত ভালোবাসা জানাই ধন্যবাদ 💜🤎🖤',
#  '👍👍',
#  'ঘোলকধাঁধা কাটিয়ে ন্যাড়া শেষ পর্যন্ত বেল তলে।',
#  '🖤🖤👌👌',
#  'খোলামেলা র লিমিট ক্রস হয় এমন মুভমেন্ট নারাখলে ড্রামা কি বাতিল হয়ে যাবে',
#  'নাবিলার পাছা ওপরের দিকে তাই ওনাকে লং ড্রেস পড়ার জন্য অনুরোধ  রইলো',
#  '😍😍😍😍😍',
#  'ফালতু নাটক এটা 👎👎👎',
#  'সিডি ভিশন ড্রামার  কাছে আবেদন জানাই এই নাটকের গানটি দয়া করে ইউটিউব এ আপলোড দিবেন ধন্যবাদ',
#  '🥀',
#  '🌹🌹🌹🌹',
#  '🥰🥰🥰💝',
#  'আমার মনে হয়  নাবিলা ছেলে, শাওন',
#  '❤❤❤',
#  'দীর্ঘ ১৫ মাস করোনা ভাইরাসের পরও যারা সুস্থ আছি তারা মন খুলে বলি আলহামদুলিল্লাহ।',
#  'নাবিলা আপু অনেক ভালবাসি💗💖💗',
#  'ছেলেরা মেয়েদের পাত্তা না দিলেও, মেয়েরা ছেলেদের পিছনে লেগে যায়,',
#  'ফালতু একটা নাটক  😡😡😡',
#  'অনেক অনেক দোয়া ও ভালোবাসা রইলো, 🥰🥰',
#  'নাটকের অভিনয় খুব সুন্দর হয়েছে,,,  সবার জন্য ভালোবাসা রইলো',
#  '<b>রসূল (সাঃ) বলেছেন-লজ্জা হচ্ছে ঈমান। ঈমান হচ্ছে জান্নাত লাভের মাধ্যম</b>',
#  'শাওন ভাইয়ের নাটক মানে অন্য রকম',
#  'নাবিলা আপু🔥🔥',
#  'অসাধারণ একটি নাটক',
#  'নাবিলা ইসলাম কে আমার একদম পছন্দ হয় না। শাওন এর জন্য নাটক টা দেখেছি',
#  'শাওন ভাই ভক্তদের দেখতে চাই <br>যারা আমার মতো শাওন ভাইয়ের নাটকের জন্য বড্ড অপেক্ষায় থাকেন।',
#  '🤍',
#  'এটা কোনো গল্প হলো',
#  'বস্তাপচা কাহিনী দিয়া নাটক তার সঙ্গে রয়েছে নায়িকাদের দেহ প্রদশর্নী।',
#  'মুসলিম সরকার চরিত্র একটা ফালতু সাথে ফাটা বোরহান',
#  'রতনার অভিনয় ভালোই লাগে না,,,কি বলেন আপনেরা',
#  'মতিন আসল নাম কি',
#  'উগন্ডারে চাইরা বরাহানের দরার দরকার',
#  'ডিসকোর অভিনয়টা অনেক ভালো হয়েছে,,,,',
#  'নাটক টা হেভি',
#  '💚💚💚💚💚💚💚💚💚',
#  'প্রেমের মাস্টার মতিন',
#  'আন্নি খান একটা কঠিন মাল',
#  'খলিল বাই আপনে রতনা ছাইরা দেন।কারন এই রতনা মে টা বালো নায়',
#  'উগান্ডা না তাকলে ভালো লাগছেনা',
#  'ভাই চিন্তা করবেনা ৩০পর্ব পরে আসবে',
#  'উগান্ডা কে দেকতে ছান কে কে লাইক দিন',
#  'অসাধারণ অনেক সুন্দর হয়েছে ভেরি নাইস',
#  'এই নাটকের হিরো দুইজন মতিন ও উগান্ডা আপনারা কি বলেন',
#  'উগান্ডা কি ছাড়া পাবে।',
#  'ডিস্ক এতদিনে একটা কোছা মারছে আছমারে।',
#  'বাকা যতই লোভি হোক মানুষটা একেবারে খারাপ না।',
#  'শুভ কামনা রইল',
#  'সবনাম ফারিয়া তোমাকে ধন্যবাদ তোমার সুন্দার অভিনয়ের জন্য',
#  'আমার একটা কথা জব্বার তালুকদার কে দেখি নাই মাডারের মধ্যে',
#  'আসেন আমরা ইসলামের পথে চলি।',
#  'উগান্ডা ছাড়া  ভালো লাগে না এই নাটক',
#  'ডিসকো র কথা টা তার ভাবী কে বলা ঠিক হয় নাই',
#  'ডিকু কথা একবারে বেমজা লাগে ওরে বাদ দেওয়ার দরকার',
#  'ডিকু কথা একবারে বেমজা লাগে ওরে বাদ দেওয়ার দরকারদরকার',
#  'মতিন ফিরে এসেছে উগান্ডার মুক্তি চাই',
#  'চেয়ারমেনের বৌরে আমার পছন্দ হয়ে গেছে',
#  'ডিচকো ঠিক বলচে আচমা আসলে হারাম জাদা',
#  'বাকার অরিজিনাল নাম কি কারো জানা থাকলে জানাইয়েন।',
#  'আমার প্রিয় নায়িকা হলো নাদিয়া',
#  'ব<br>রত্ন মালটা একটা জিনিস',
#  'মানুষ মরলে অন্যরা কিছুটা নরম হয়।<br>কয়েক দিন গেছে এখন আর জমি দিতে চাই না',
#  'বাকা ভাই সুন্দর একটা  কাজ করছে।',
#  'বোরহান ভাই আপনার কি একটা সাট একজোরা  জোতা।',
#  'আমি আগে বলছিলাম চেরমানের একটা সন্তান থাকা দরকার আমি অন্যরত করে বলছি',
#  'উগান্ডার জামিন হোক <br>আপনারা সবাই কি বলেন',
#  'এই নাটকে সবচেয়ে মতিনের অভিনয় ভালো লাগে',
#  'উগান্ডাকে ফিরিয়ে আনা হোক&quot;&quot;&quot;',
#  'এমন বন্ধু যখতে দরকার',
#  'আসমা ভাবি তুমি আর তোমার ভাইয়ের বউ তো হিজলা তুমি তো এখনো পারলা না',
#  'দিবার বাচ্ছা কিভাবে হবে আমি তো মিল পাচ্ছি না, বিয়ের করছে কয়দিন হইছে, কারুণ রসুলপুর যাত্রা আইছে এক মাসের জন্য সেই যাত্রা এখনো শেষ হয়নাই,  তারমানে বিয়ে করছে ১০/১৫দিন হবে এর মাঝে বাচ্ছা কিভাবে সম্ভব,,,,',
#  'বতগহুন',
#  'আমরা মনে হয় বাচ্চা দেখতে পারবো<br>,,,,উগান্ডা নাই বলে,,,, নাটকের সুন্দর <br>কমে যাচ্ছে',
#  'ব্যাখা তো সেই মনের ভালো মানুষ,, বন্ধুর সাথে বেইমানি করে নাই,, মন্টু রে সব ই বলে দিছে আইসা,, মন্টুর ভাবির কথা সব বলে দিছে আইসা মন্টুর কাছে',
#  'অনেক সুন্দর হয়েছে',
#  'সাত্তারের বৌ এবং তার শালি একটা রেনডী মহিলা তাদের গোটা বাংলাদেশের মানুষ জন দিয়ে চুদালেও তাদের সেক্স মিটবে না ।',
#  'সবাই জাত অভিনেতা',
#  'উগান্ডা ইস দ্যা বেষ্ট। আমার মনে হয় মার্ডার টা টেডি করছে।',
#  'ওগানডা ছারা ভাল লাগেনা নাটক',
#  'উগান্ডা ছারা বকুলপুর প্রানহীন',
#  'বাকার অভিনয় বেশ ভালো হয়েছে',
#  '১২৬ পর্ব কই রে ভাই।',
#  'কেমন জানি নাটক টা ভিতরে একটা চাহিদা থেকে জায় সেই চাহিদার হলো উগান্ডা। দুত ভাতে জেমন লবন না হলে ভালো  লাগেনা তেমর উগান্ডা ছারা এই নাটক টাই ভালো লাগে না। বুজলেন ভাই',
#  'ভাই আরগুলা পামু জানাইবেন',
#  '🇧🇩আজ কিছু লেকবনা কারণ 🇧🇩<br>🇧🇩মনটা ভালো না🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩',
#  'উগান্ডা কে নিদ্দোশ প্রমান করা হোক, এবং খুনি কে তারে তারাতারি বের করা হোক, পরিচালক সাহেব আর কত কইতাম উগান্ডা কে সব পর্বে দেখতে চাই।',
#  '১শ ২৬ পব দেন',
#  'নাইচ',
#  'চেয়ারম্যানের বউয়ের আসল নামটা কি,, কেউ কি বলবেন???',
#  'এক কথায় অসাধরন নাটক,আমার জিবনের প্রথম এমন ভাবে নাটক দেখতেছি, সকাল নয়টা থেকে, রাতের তিন টা পর্যন্ত একটানা, দেখলাম।।',
#  '২৬ হতে পর্ব যা আছে সব পর্বের অক্কায় আছি',
#  'আসুন আমরা পাচ ওয়াক্ত নামাজ কয়েম করি',
#  'আল্লাহ সবাই আশা পুরাই করে চাইতে হবে নামাজ পড়ে দোয়া করতে হবে',
#  'আগামী ১২৬পর্ব দেখতে চাই',
#  'উগান্ডা ছাড়া ভালো লাগে না',
#  'এমন শয়তান ভাবির সন্তান না হওয়ার দরকার।',
#  'মাস্টার কই',
#  'টেডি ঠিকে বাপ হবে!?তোরা হিজলা! আটখুরা!তোরা বাঞ্জাগাভীর বিচ!!',
#  'কমেন্ট করলে দীপ্ত টিভি  রিপ্লে দেয় না',
#  'দারুণ হয়েছে এটা সত্যি কুকুরের লেজজেমন শোয়া হয় না খারাপ লোকের সঙ্গে থেকনা',
#  'উগান্ডা কে আর দেখতে চাই না সাথে বাকা কেও বাদ দেওয়া উচিত',
#  'এতো পরিচ্ছন্ন নিষ্পাপ প্রেম.. এতো স্বতঃস্ফূর্ত অভিনয়.. অপূর্ব তো চিরকালই তুলনাহীন,.. তিশাও অনন্য। বাংলাদেশের নাটকে মজে আছি..  অনেক ভালোবাসা আর শুভেচ্ছা কলকাতা থেকে ❤️💗💕',
#  '👌👌👌👌👌👌🌹🌹🌹🌹🌹🌹🌹',
#  'অদ্ভুত সুন্দর নাটক।বার বার দেখি ,আমার অবুঝ দিনের স্রীতিগুলো মনে পরে যায়।',
#  '২০২১ সালে নাটকটি কে কে দেখেছেন?',
#  'অপুরবকে মেহেজাবিনের সাথে ভালো লাগে',
#  'প্লিজ তারাতারি অবুঝ দিনের গল্প ৩ বের করেন🙏🙏🙏🙏🙏🙏',
#  'আর কতোদিন অপেক্ষা করতে হবে অবুঝ দিনের গল্প ৩ দেখার জন্য????😒😒😒😒😒😒',
#  'লাস্ট পর্ব এখন ও পেলাম না',
#  'ভারি সুন্দর লাগলো। এত মধুর অবুঝ দিন, অবুঝ প্রেম💞💞💞',
#  'গল্পটা খুব সুন্দর তানজিন তিশা অভিনয়টা খুব ভালো করেছে অপূর্ব তেমনি ভালো',
#  'মাচ বেটার',
#  'এই নাটকের ৩ নং পার্ট কবে হবে???',
#  'আচ্ছা থিমসং টা কোন মুভি থেকে নেওয়া? প্লিজ কারো জানা থাকলে জানাবেন।।',
#  'অসম্ভব সুন্দর, অনবদ্য, প্রানবন্ত অভিনয়! এক কথায় অসাধারণ!!  অভিনেতা, অভিনেত্রী, পরিচালক, গল্পকার, নাট্যকার কেউ ই কম নয়! এগিয়ে যাক বাংলার নাটক শিল্প।',
#  'লাস্ট পারট কবে আসবে বাল😑😑😑',
#  'তানজিন তিশার নাটক খুব একটা দেখা হয় না । এই নাটকে তার অভিনয় দেখে মুদ্ধ হয়েছি । সব মিলিয়ে নাটক টা দারুন উপভোগ করেছি।',
#  'এই রকম একটা নাটক আমি দেখিনাই আগে  বিশ্বাস হচ্ছে নাহ',
#  'এই দু বছর আমি কোথায় ছিলাম,?  এত সুন্দর একটা নাটক আমার কাছ থেকে লুকিয়ে ছিল',
#  '❤❤❤',
#  'সাইকেলের দৃশ্যটায় অতীত মনে পড়ে গেলো।🙂',
#  'অসাধারণ ভালো হয়েছে  নাটক। যতবার দেখি ততবারই ভালো লাগে। নাম্বার ওয়ান',
#  'দারুন মজার রোমান্টিক নাটক। আমার প্রিয় অভিনেতা অপূর্ব ভাই ও তানজিন তিশা বোনের অভিনয় সমৃদ্ধ ও আমার প্রিয় পরিচালক শিহাব শাহীন সাহেবের সৃষ্টিশীল চিন্তাভাবনার ফসল এই নাটক টা দেখে দারুন ভালো লাগলো। ধন্যবাদ।<br><br>অসীম দত্ত, কলকাতা, ইন্ডিয়া।',
#  'আবারও দেখলাম, এত ভালো লাগে কেরে আমার,। ❤️😍❤️',
#  'কে কে প্রিয় নবীকে ভালোবাসো তাদের কে  বলি একটা লাইক দিয়ে জান',
#  'অসাধারণ, মনোমুগ্ধকর নাটক',
#  'আনেক দিন পরে আনেক সুন্দর একটা নাটক দেখতে পেলাম ❤️❤️❤️',
#  '❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#  'তিশা যে কবিতাটা বলে সেটার নাম আর লেখক কে?',
#  'অনেকে সুন্দর হয়েছে🥰❤️❤️❤️💝',
#  'অনেক সুন্দর, অনেক ভালো। নাটক হলে এরকম হওয়া ভালো। অপূর্ব আর তানজিন তিশা জুটি আরোও দেখতে চাই।',
#  'ধন্যাবাদ সবাইকে এত ভালোবাসার  জন্য ♥️',
#  'খুবই ভালো নাটক😍😍😘',
#  'অসাধারণ',
#  'অসাধারণ অভিনয়,  অসম্ভব সুন্দর 👍👍👍',
#  'অন্য একটা নাটক দেখতে চেয়েছিলাম বাট কমেন্ট বক্সে এই নাটকের চাহিদা দেখে দেখতে আসা আমি।।।',
#  'অসাধারন এই নাটকটা দেখে আগের অনেক কথা গুলো মনে পরে গেলো তবে দিন দিন বড় হচ্ছি আর বাস্তবের মুখামুখি হচ্ছি',
#  'অসম্ভব  সুন্দর',
#  '২০২১ এ নাটক টা কে কে দেখছেন.?',
#  'আজ আগস্টের ১৮ তারিখ।।নাটকটা দেখছি প্রথম❣️🖤',
#  '২০২১ এ কে কে নাটকটি দেখছেন 🤣🤣',
#  'ভজা মেম্বার',
#  'আজ থেকে শুরু করালম ১৩ তারিখ থেকে',
#  'দেখা শুরু করলান',
#  'এবার সহ চার বার দেখতে ছি',
#  'আগের মিউজিক টা ভালো ছিলো',
#  'যার টা দেইখা ওযু করে সেইতো ওযু পারেনা',
#  'ভজা মেম্বার সেই😁😁',
#  'সুবাহানআল্লাহ ❤️❤️❤️',
#  'মোট কতগুলো পর্ব এই নাটকের? কেউ কি অনুগ্রহ পূর্বক জানাবেন !',
#  'নাটক টা হেভি',
#  'ফেসবুক থেকে দেখে আসলাম দেখতে 😌<br>ভারত থেকে বলছি 😊<br>আচ্ছা এই নাটক টা আসলে কবেকার ??',
#  '০৬/০৭/২০২১ আজ থেকে নাটকটি দেখা শুরু করলাম।',
#  'কোন দরকার আছে নাটকের আসল ব্যাকগ্ৰাউনড মিউজিক বদলানোর ?',
#  'নাটক আজকে থেকেই দেখা  <br>05,07,2021 তারিখের পর থেকেই 📢📢📢',
#  'আমি আজ থেকে দেখা শুরু করলাম <br>তারিখ :-০৫-০৭-২০২১<br>সময়:-৯:০৪ সকাল',
#  'আজ থেকে দেখা শুরু করলাম৷ ৪ /৭/২০২১',
#  'ফেসবুকে এই নাটকের ক্লিপ দেখে ০৪-০৭-২০২১ (রবিবার) থেকে দেখা শুরু করলাম।। মোশাররফ করিম বলে কথা🥰',
#  'ফেসবুক এ আগে ছোট ছোট ক্লিপ দেখতাম আজ ফুল নাটক দেখা শুরু করলাম ❤️ আসা করি ভালো হবে ❤️। সোনালি যুগে নাটক 🥰',
#  'দ্বিতীয় বারের মত শুরু করলাম',
#  '💝💝',
#  'কিচলুর অভিনয় অসাধারন।',
#  ...]

# %%
def create_dataset_csv(lines, filename):
    df = pd.DataFrame(lines, columns=["text"])
    df.to_csv(filename, index=False)

# %%
create_dataset_csv(comments,"comment_final.csv")
